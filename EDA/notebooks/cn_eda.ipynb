# %% [markdown]
# # C–N dataset analysis

# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import QED, Descriptors
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# ### Show shape and features of dataset

# %%
data_df = pd.read_csv('cn_full.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_df
# Out:
#                                               References  \
# 0      Article; Melzer, Marie M.; Mossin, Susanne; Da...
# 1      Article; Kuegler, Fabian; Ermert, Johannes; Ka...
# 2      Patent; Worldwide Show Corporation; Si Kete·bi...
# 3      Patent; CONCERT PHARMACEUTICALS, INC.; LIU, Ju...
# 4      Patent; ZHENJIANG SHENG AN PHARMACEUTICAL CO L...
# ...                                                  ...
# 36514  Patent; Samsung Display Co., Ltd.; Lee, Jungsu...
# 36515  Patent; Doosan Co., Ltd; Choi Tae-jin; (52 pag...
# 36516  Patent; DOOSAN CORP; Doosan Co., Ltd; HAN SONG...
# 36517  Patent; Alberte, Randall S.; Roschek, JR., Wil...
# 36518  Article; Ejmocki, Zdzislaw; Eckstein, Zygmunt;...
#
#                                          Links to Reaxys  \
# 0      https://www.reaxys.com/reaxys/secured/hopinto....
# 1      https://www.reaxys.com/reaxys/secured/hopinto....
# 2      https://www.reaxys.com/reaxys/secured/hopinto....
# 3      https://www.reaxys.com/reaxys/secured/hopinto....
# 4      https://www.reaxys.com/reaxys/secured/hopinto....
# ...                                                  ...
# 36514  https://www.reaxys.com/reaxys/secured/hopinto....
# 36515  https://www.reaxys.com/reaxys/secured/hopinto....
# 36516  https://www.reaxys.com/reaxys/secured/hopinto....
# 36517  https://www.reaxys.com/reaxys/secured/hopinto....
# 36518  https://www.reaxys.com/reaxys/secured/hopinto....
#
#                                               reactant 1  \
# 0                                          BrC1=CC=CC=C1
# 1                                               C1CNCCN1
# 2                             ClC1=CC=C(Br)C(=C1)N(=O)=O
# 3                                       BrC1=CC=CC(I)=C1
# 4      [2H]C([2H])([2H])C1=CC=C(SC2=C(Br)C=CC=C2)C(=C...
# ...                                                  ...
# 36514      BrC1=CC=C(C=C1)N1C2=C(C=CC=C2)N=C1C1=CC=CC=C1
# 36515  BrC1=CC(=CC=C1)C1=NC(=NC(=N1)C1=CC=CC=C1)C1=CC...
# 36516                                     ClC1=CC=CC=C1I
# 36517                             ClC1=CC=C(C=C1)N(=O)=O
# 36518               ClCS(=O)(=O)C1=CC=C(Cl)C(=C1)N(=O)=O
#
#                                               reactant 2  \
# 0                                     [15NH2]C1=CC=CC=C1
# 1                                    [18F]C1=CC=C(I)C=C1
# 2      [2H]C([2H])([2H])C([2H])(C1=C(N)C=CC=C1)C([2H]...
# 3      [2H]C([2H])([2H])C(C1=CC=C(N)C(=C1)N(=O)=O)(C(...
# 4                                 CC(C)(C)OC(=O)N1CCNCC1
# ...                                                  ...
# 36514          N1C=CC2=C3C(SC4=CC=CC=C34)=CC3=CC=CC1=C23
# 36515                  N1C2=C(C=CC=C2)C2=C1C=CC1=NSN=C21
# 36516                   NC1=C(S)C=C2OC3=C(OC2=C1)C=CC=C3
# 36517                                    NC1=CC=C(S)C=C1
# 36518                                               NCCS
#
#                                                  Product  Yield Halide  \
# 0                         [15NH](C1=CC=CC=C1)C1=CC=CC=C1   0.91     Br
# 1                             [18F]C1=CC=C(C=C1)N1CCNCC1   0.95      I
# 2      [2H]C([2H])([2H])C([2H])(C1=C(NC2=C(C=C(Cl)C=C...   0.59     Br
# 3      [2H]C([2H])([2H])C(C1=CC=C(NC2=CC(Br)=CC=C2)C(...   0.70      I
# 4      [2H]C([2H])([2H])C1=CC(=C(SC2=C(C=CC=C2)N2CCN(...   0.66     Br
# ...                                                  ...    ...    ...
# 36514  S1C2=CC3=CC=CC4=C3C(C=CN4C3=CC=C(C=C3)N3C4=CC=...   0.72     Br
# 36515  S1N=C2C=CC3=C(C2=N1)C1=C(C=CC=C1)N3C1=CC=CC(=C...   0.89     Br
# 36516    SC1=C(NC2=C(Cl)C=CC=C2)C=C2OC3=C(OC2=C1)C=CC=C3   0.42      I
# 36517                SC1=CC=C(NC2=CC=C(C=C2)N(=O)=O)C=C1   0.81     Cl
# 36518             SCCNC1=C(C=C(C=C1)S(=O)(=O)CCl)N(=O)=O   0.92     Cl
#
#       Solvent 1 Solvent 2 Solvent 3 Solvent 4 Reagent 1 Reagent 2 Reagent 3  \
# 0            S1       NaN       NaN       NaN        M2        L2        B5
# 1            S4       NaN       NaN       NaN        M2        B3       L12
# 2            S1       NaN       NaN       NaN       L15        M2        B3
# 3            S1       NaN       NaN       NaN        B1       NaN       NaN
# 4            S1       NaN       NaN       NaN        L1        M5        B1
# ...         ...       ...       ...       ...       ...       ...       ...
# 36514        S1       NaN       NaN       NaN        M2        L2       NaN
# 36515        S1       NaN       NaN       NaN        M2        L2        B1
# 36516        S1       NaN       NaN       NaN        L2        M3        B1
# 36517        S3       NaN       NaN       NaN        B2       NaN       NaN
# 36518       NaN       NaN       NaN       NaN        B7       NaN       NaN
#
#       Reagent 4 Reagent 5 Reagent 6 Reagent 7
# 0           NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN
# 3           NaN        M2        L3       NaN
# 4           NaN       NaN       NaN       NaN
# ...         ...       ...       ...       ...
# 36514       NaN       NaN       NaN       NaN
# 36515       NaN       NaN       NaN       NaN
# 36516       NaN       NaN       NaN       NaN
# 36517       NaN       NaN       NaN       NaN
# 36518       NaN       NaN       NaN       NaN
#
# [36519 rows x 18 columns]

# %% [markdown]
# ### Build new dataset for statistical & chemical space analysis

# %%
pdt_df = data_df[['Product', 'Yield']]

# %%
pdt_df
# Out:
#                                                  Product  Yield
# 0                         [15NH](C1=CC=CC=C1)C1=CC=CC=C1   0.91
# 1                             [18F]C1=CC=C(C=C1)N1CCNCC1   0.95
# 2      [2H]C([2H])([2H])C([2H])(C1=C(NC2=C(C=C(Cl)C=C...   0.59
# 3      [2H]C([2H])([2H])C(C1=CC=C(NC2=CC(Br)=CC=C2)C(...   0.70
# 4      [2H]C([2H])([2H])C1=CC(=C(SC2=C(C=CC=C2)N2CCN(...   0.66
# ...                                                  ...    ...
# 36514  S1C2=CC3=CC=CC4=C3C(C=CN4C3=CC=C(C=C3)N3C4=CC=...   0.72
# 36515  S1N=C2C=CC3=C(C2=N1)C1=C(C=CC=C1)N3C1=CC=CC(=C...   0.89
# 36516    SC1=C(NC2=C(Cl)C=CC=C2)C=C2OC3=C(OC2=C1)C=CC=C3   0.42
# 36517                SC1=CC=C(NC2=CC=C(C=C2)N(=O)=O)C=C1   0.81
# 36518             SCCNC1=C(C=C(C=C1)S(=O)(=O)CCl)N(=O)=O   0.92
#
# [36519 rows x 2 columns]

# %% [markdown]
# ### Calculate representative molecular descriptors in RDKit
# 16 properties are computed for each SMILES with successful RDKit mol generation.<br>
# Unsuccessful mol generation returns null property vectors.

# %%
MolWt = []
MolLogP = []
TPSA = []
HeavyAtomCount = []
NumHeteroatoms = []
NumValenceElectrons = []
NumHAcceptors = []
NumHDonors = []
NumRotatableBonds = []
RingCount = []
NumAromaticHeterocycles = []
NumAromaticCarbocycles = []
NumSaturatedHeterocycles = []
NumSaturatedCarbocycles = []
FractionCSP3 = []
QED = []

for smi in pdt_df['Product']:
    if not Chem.MolFromSmiles(smi) == None:
        mol = Chem.MolFromSmiles(smi)
        MolWt.append(Descriptors.MolWt(mol))
        MolLogP.append(Descriptors.MolLogP(mol))
        TPSA.append(Descriptors.TPSA(mol))
        HeavyAtomCount.append(Descriptors.HeavyAtomCount(mol))
        NumHeteroatoms.append(Descriptors.NumHeteroatoms(mol))
        NumValenceElectrons.append(Descriptors.NumValenceElectrons(mol))
        NumHAcceptors.append(Descriptors.NumHAcceptors(mol))
        NumHDonors.append(Descriptors.NumHDonors(mol))
        NumRotatableBonds.append(Descriptors.NumRotatableBonds(mol))
        RingCount.append(Descriptors.RingCount(mol))
        NumAromaticHeterocycles.append(Descriptors.NumAromaticHeterocycles(mol))
        NumAromaticCarbocycles.append(Descriptors.NumAromaticCarbocycles(mol))
        NumSaturatedHeterocycles.append(Descriptors.NumSaturatedHeterocycles(mol))
        NumSaturatedCarbocycles.append(Descriptors.NumSaturatedCarbocycles(mol))
        FractionCSP3.append(Descriptors.FractionCSP3(mol))
        QED.append(Chem.QED.default(mol))
    else:
        MolWt.append('')
        MolLogP.append('')
        TPSA.append('')
        HeavyAtomCount.append('')
        NumHeteroatoms.append('')
        NumValenceElectrons.append('')
        NumHAcceptors.append('')
        NumHDonors.append('')
        NumRotatableBonds.append('')
        RingCount.append('')
        NumAromaticHeterocycles.append('')
        NumAromaticCarbocycles.append('')
        NumSaturatedHeterocycles.append('')
        NumSaturatedCarbocycles.append('')
        FractionCSP3.append('')
        QED.append('')

pdt_df['MolWt'] = MolWt
pdt_df['MolLogP'] = MolLogP
pdt_df['TPSA'] = TPSA
pdt_df['HeavyAtomCount'] = HeavyAtomCount
pdt_df['NumHeteroatoms'] = NumHeteroatoms
pdt_df['NumValenceElectrons'] = NumValenceElectrons
pdt_df['NumHAcceptors'] = NumHAcceptors
pdt_df['NumHDonors'] = NumHDonors
pdt_df['NumRotatableBonds'] = NumRotatableBonds
pdt_df['RingCount'] = RingCount
pdt_df['NumAromaticHeterocycles'] = NumAromaticHeterocycles
pdt_df['NumAromaticCarbocycles'] = NumAromaticCarbocycles
pdt_df['NumSaturatedHeterocycles'] = NumSaturatedHeterocycles
pdt_df['NumSaturatedCarbocycles'] = NumSaturatedCarbocycles
pdt_df['FractionCSP3'] = FractionCSP3
pdt_df['QED'] = QED
# Out:
# RDKit ERROR: [15:10:44] Explicit valence for atom # 0 N, 4, is greater than permitted
# RDKit ERROR: [15:10:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [15:10:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [15:10:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [15:10:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [15:10:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [15:10:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [15:10:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [15:11:12] Explicit valence for atom # 2 B, 4, is greater than permitted
# RDKit ERROR: [15:11:12] Explicit valence for atom # 2 B, 4, is greater than permitted
# RDKit ERROR: [15:11:19] Explicit valence for atom # 11 B, 4, is greater than permitted
# RDKit ERROR: [15:11:23] Explicit valence for atom # 12 B, 4, is greater than permitted
# RDKit ERROR: [15:11:37] Explicit valence for atom # 18 B, 4, is greater than permitted
# RDKit ERROR: [15:11:39] Explicit valence for atom # 17 B, 4, is greater than permitted
# RDKit ERROR: [15:12:04] Explicit valence for atom # 19 B, 4, is greater than permitted
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
pdt_df
# Out:
#                                                  Product  Yield    MolWt  \
# 0                         [15NH](C1=CC=CC=C1)C1=CC=CC=C1   0.91   170.22
# 1                             [18F]C1=CC=C(C=C1)N1CCNCC1   0.95  179.229
# 2      [2H]C([2H])([2H])C([2H])(C1=C(NC2=C(C=C(Cl)C=C...   0.59  297.793
# 3      [2H]C([2H])([2H])C(C1=CC=C(NC2=CC(Br)=CC=C2)C(...   0.70  358.283
# 4      [2H]C([2H])([2H])C1=CC(=C(SC2=C(C=CC=C2)N2CCN(...   0.66  404.609
# ...                                                  ...    ...      ...
# 36514  S1C2=CC3=CC=CC4=C3C(C=CN4C3=CC=C(C=C3)N3C4=CC=...   0.72  541.679
# 36515  S1N=C2C=CC3=C(C2=N1)C1=C(C=CC=C1)N3C1=CC=CC(=C...   0.89  532.632
# 36516    SC1=C(NC2=C(Cl)C=CC=C2)C=C2OC3=C(OC2=C1)C=CC=C3   0.42  341.819
# 36517                SC1=CC=C(NC2=CC=C(C=C2)N(=O)=O)C=C1   0.81  246.291
# 36518             SCCNC1=C(C=C(C=C1)S(=O)(=O)CCl)N(=O)=O   0.92  310.784
#
#        MolLogP   TPSA HeavyAtomCount NumHeteroatoms NumValenceElectrons  \
# 0       3.4302  12.03             13              1                  64
# 1       1.2353  15.27             13              3                  70
# 2       5.1152  55.17             20              5                 104
# 3       5.3984  55.17             21              5                 110
# 4      5.51174  32.78             28              5                 150
# ...        ...    ...            ...            ...                 ...
# 36514   10.336  21.06             41              4                 192
# 36515   7.9744  69.38             40              7                 188
# 36516   6.2703  30.49             23              5                 114
# 36517   3.6271  55.17             17              5                  86
# 36518   1.9065  89.31             18              9                 100
#
#       NumHAcceptors NumHDonors NumRotatableBonds RingCount  \
# 0                 1          1                 2         2
# 1                 2          1                 1         2
# 2                 3          1                 6         2
# 3                 3          1                 3         2
# 4                 4          0                 5         3
# ...             ...        ...               ...       ...
# 36514             4          0                 3         9
# 36515             7          0                 4         8
# 36516             4          2                 2         4
# 36517             4          2                 3         2
# 36518             6          2                 6         1
#
#       NumAromaticHeterocycles NumAromaticCarbocycles NumSaturatedHeterocycles  \
# 0                           0                      2                        0
# 1                           0                      1                        1
# 2                           0                      2                        0
# 3                           0                      2                        0
# 4                           0                      2                        1
# ...                       ...                    ...                      ...
# 36514                       2                      6                        0
# 36515                       3                      5                        0
# 36516                       0                      3                        0
# 36517                       0                      2                        0
# 36518                       0                      1                        0
#
#       NumSaturatedCarbocycles FractionCSP3       QED
# 0                           0            0  0.680675
# 1                           0          0.4   0.69733
# 2                           0          0.2    0.5948
# 3                           0         0.25  0.590474
# 4                           0     0.434783  0.657547
# ...                       ...          ...       ...
# 36514                       0            0  0.221816
# 36515                       0            0   0.22985
# 36516                       0            0  0.421061
# 36517                       0            0  0.493719
# 36518                       0     0.333333  0.362436
#
# [36519 rows x 18 columns]

# %% [markdown]
# ### Convert property vector dtypes to float64

# %%
pdt_df.dtypes
# Out:
# Product                      object
# Yield                       float64
# MolWt                        object
# MolLogP                      object
# TPSA                         object
# HeavyAtomCount               object
# NumHeteroatoms               object
# NumValenceElectrons          object
# NumHAcceptors                object
# NumHDonors                   object
# NumRotatableBonds            object
# RingCount                    object
# NumAromaticHeterocycles      object
# NumAromaticCarbocycles       object
# NumSaturatedHeterocycles     object
# NumSaturatedCarbocycles      object
# FractionCSP3                 object
# QED                          object
# dtype: object

# %%
cols = list(pdt_df.columns)

# %%
cols.pop(0)
# Out:
# 'Product'

# %%
pdt_df[cols] = pdt_df[cols].apply(pd.to_numeric, errors='coerce')

# %%
pdt_df.dtypes
# Out:
# Product                      object
# Yield                       float64
# MolWt                       float64
# MolLogP                     float64
# TPSA                        float64
# HeavyAtomCount              float64
# NumHeteroatoms              float64
# NumValenceElectrons         float64
# NumHAcceptors               float64
# NumHDonors                  float64
# NumRotatableBonds           float64
# RingCount                   float64
# NumAromaticHeterocycles     float64
# NumAromaticCarbocycles      float64
# NumSaturatedHeterocycles    float64
# NumSaturatedCarbocycles     float64
# FractionCSP3                float64
# QED                         float64
# dtype: object

# %%
pdt_df
# Out:
#                                                  Product  Yield       MolWt  \
# 0                         [15NH](C1=CC=CC=C1)C1=CC=CC=C1   0.91  170.220109
# 1                             [18F]C1=CC=C(C=C1)N1CCNCC1   0.95  179.228938
# 2      [2H]C([2H])([2H])C([2H])(C1=C(NC2=C(C=C(Cl)C=C...   0.59  297.792712
# 3      [2H]C([2H])([2H])C(C1=CC=C(NC2=CC(Br)=CC=C2)C(...   0.70  358.282916
# 4      [2H]C([2H])([2H])C1=CC(=C(SC2=C(C=CC=C2)N2CCN(...   0.66  404.608611
# ...                                                  ...    ...         ...
# 36514  S1C2=CC3=CC=CC4=C3C(C=CN4C3=CC=C(C=C3)N3C4=CC=...   0.72  541.679000
# 36515  S1N=C2C=CC3=C(C2=N1)C1=C(C=CC=C1)N3C1=CC=CC(=C...   0.89  532.632000
# 36516    SC1=C(NC2=C(Cl)C=CC=C2)C=C2OC3=C(OC2=C1)C=CC=C3   0.42  341.819000
# 36517                SC1=CC=C(NC2=CC=C(C=C2)N(=O)=O)C=C1   0.81  246.291000
# 36518             SCCNC1=C(C=C(C=C1)S(=O)(=O)CCl)N(=O)=O   0.92  310.784000
#
#         MolLogP   TPSA  HeavyAtomCount  NumHeteroatoms  NumValenceElectrons  \
# 0       3.43020  12.03            13.0             1.0                 64.0
# 1       1.23530  15.27            13.0             3.0                 70.0
# 2       5.11520  55.17            20.0             5.0                104.0
# 3       5.39840  55.17            21.0             5.0                110.0
# 4       5.51174  32.78            28.0             5.0                150.0
# ...         ...    ...             ...             ...                  ...
# 36514  10.33600  21.06            41.0             4.0                192.0
# 36515   7.97440  69.38            40.0             7.0                188.0
# 36516   6.27030  30.49            23.0             5.0                114.0
# 36517   3.62710  55.17            17.0             5.0                 86.0
# 36518   1.90650  89.31            18.0             9.0                100.0
#
#        NumHAcceptors  NumHDonors  NumRotatableBonds  RingCount  \
# 0                1.0         1.0                2.0        2.0
# 1                2.0         1.0                1.0        2.0
# 2                3.0         1.0                6.0        2.0
# 3                3.0         1.0                3.0        2.0
# 4                4.0         0.0                5.0        3.0
# ...              ...         ...                ...        ...
# 36514            4.0         0.0                3.0        9.0
# 36515            7.0         0.0                4.0        8.0
# 36516            4.0         2.0                2.0        4.0
# 36517            4.0         2.0                3.0        2.0
# 36518            6.0         2.0                6.0        1.0
#
#        NumAromaticHeterocycles  NumAromaticCarbocycles  \
# 0                          0.0                     2.0
# 1                          0.0                     1.0
# 2                          0.0                     2.0
# 3                          0.0                     2.0
# 4                          0.0                     2.0
# ...                        ...                     ...
# 36514                      2.0                     6.0
# 36515                      3.0                     5.0
# 36516                      0.0                     3.0
# 36517                      0.0                     2.0
# 36518                      0.0                     1.0
#
#        NumSaturatedHeterocycles  NumSaturatedCarbocycles  FractionCSP3  \
# 0                           0.0                      0.0      0.000000
# 1                           1.0                      0.0      0.400000
# 2                           0.0                      0.0      0.200000
# 3                           0.0                      0.0      0.250000
# 4                           1.0                      0.0      0.434783
# ...                         ...                      ...           ...
# 36514                       0.0                      0.0      0.000000
# 36515                       0.0                      0.0      0.000000
# 36516                       0.0                      0.0      0.000000
# 36517                       0.0                      0.0      0.000000
# 36518                       0.0                      0.0      0.333333
#
#             QED
# 0      0.680675
# 1      0.697330
# 2      0.594800
# 3      0.590474
# 4      0.657547
# ...         ...
# 36514  0.221816
# 36515  0.229850
# 36516  0.421061
# 36517  0.493719
# 36518  0.362436
#
# [36519 rows x 18 columns]

# %% [markdown]
# ## Property vector statistical analysis

# %%
stats = pdt_df.describe().round(decimals=3)
stats.to_csv('cn_stats.csv', float_format='%g')
stats
# Out:
#            Yield      MolWt    MolLogP       TPSA  HeavyAtomCount  \
# count  36519.000  36504.000  36504.000  36504.000       36504.000
# mean       0.699    310.300      4.281     41.023          22.272
# std        0.229    123.812      2.279     32.613           8.887
# min        0.000    107.156     -1.441      3.010           8.000
# 25%        0.570    216.240      2.870     12.470          16.000
# 50%        0.750    279.325      3.763     33.200          20.000
# 75%        0.880    376.400      5.166     58.440          27.000
# max        1.000   2527.861     30.826    355.670         172.000
#
#        NumHeteroatoms  NumValenceElectrons  NumHAcceptors  NumHDonors  \
# count       36504.000            36504.000      36504.000   36504.000
# mean            4.237              114.149          3.128       0.673
# std             2.820               44.884          2.018       0.771
# min             1.000               42.000          1.000       0.000
# 25%             2.000               82.000          2.000       0.000
# 50%             4.000              102.000          3.000       1.000
# 75%             6.000              136.000          4.000       1.000
# max            40.000              960.000         39.000       8.000
#
#        NumRotatableBonds  RingCount  NumAromaticHeterocycles  \
# count          36504.000  36504.000                36504.000
# mean               3.598      3.022                    0.452
# std                2.804      1.643                    0.691
# min                1.000      1.000                    0.000
# 25%                2.000      2.000                    0.000
# 50%                3.000      3.000                    0.000
# 75%                5.000      4.000                    1.000
# max              114.000     12.000                    7.000
#
#        NumAromaticCarbocycles  NumSaturatedHeterocycles  \
# count               36504.000                 36504.000
# mean                    2.093                     0.292
# std                     1.292                     0.530
# min                     1.000                     0.000
# 25%                     1.000                     0.000
# 50%                     2.000                     0.000
# 75%                     2.000                     1.000
# max                     9.000                     4.000
#
#        NumSaturatedCarbocycles  FractionCSP3        QED
# count                36504.000     36504.000  36504.000
# mean                     0.067         0.225      0.603
# std                      0.361         0.191      0.197
# min                      0.000         0.000      0.015
# 25%                      0.000         0.067      0.481
# 50%                      0.000         0.182      0.647
# 75%                      0.000         0.400      0.757
# max                      5.000         0.917      0.948

# %% [markdown]
# ## Plot yield distribution
# Note 'ax.hist' can be replaced with 'ax.kde' for kernel density estimation

# %%
yield_hist, ax = plt.subplots(figsize=(5, 5))
ax.hist(pdt_df['Yield'], bins=20, rwidth=0.9, color=plt.get_cmap('winter')(0.27))
ax.set_xlabel('yield')
ax.set_ylabel('frequency')
yield_hist.savefig('cn_yield_hist.png', dpi=300, bbox_inches='tight')

# %%
plt.close(yield_hist)

# %% [markdown]
# ## Plot descriptor distributions
# Again, 'axis.hist' can be replaced with 'axis.kde'

# %%
props = pdt_df.drop(['Product', 'Yield'], axis=1)

# %%
prop_hists, axes = plt.subplots(4, 4, figsize=(20, 20))
cmap = plt.get_cmap('winter')
kn = np.arange(len(props.columns))
for col, axis, k in zip(props.columns, axes.flatten(), kn):
    series = props[col]
    #removing outliers to avoid sparse tail distribution
    data = series[series.between(series.quantile(.01), series.quantile(.99))]
    axis.hist(data, rwidth=0.9, color=cmap(float(0.95*k)/kn.max()))
    axis.set_xlabel(col, fontsize=12)
    if (k+1)%4 == 1%4:
        axis.set_ylabel('frequency')
prop_hists.savefig('cn_prop_hists.png', dpi=300, bbox_inches='tight')

# %%
plt.close(prop_hists)

# %% [markdown]
# # C–N dictionary analysis

# %%
dict_df = pd.read_csv('cn_dict_final.csv')
dict_df.head()
# Out:
#   additive_bin               additive_name  additive base_bin  \
# 0           A1            18-crown-6 ether       455       B1
# 1           A2  tetrabutylammomium bromide       372       B2
# 2           A3                8-quinolinol       206       B3
# 3           A4    dimethylaminoacetic acid       167       B4
# 4           A5          1,1'-bi-2-naphthol       162       B5
#
#                  base_name    base ligand_bin  \
# 0      sodium t-butanolate  9103.0         L1
# 1      potassium carbonate  7129.0         L2
# 2        caesium carbonate  6957.0         L3
# 3      potassium phosphate  3274.0         L4
# 4  potassium tert-butylate  2167.0         L5
#
#                                          ligand_name  ligand metal_bin  \
# 0       2,2'-bis-(diphenylphosphino)-1,1'-binaphthyl  3014.0        M1
# 1                           tri-tert-butyl phosphine  2137.0        M2
# 2  4,5-bis(diphenylphos4,5-bis(diphenylphosphino)...  1995.0        M3
# 3                       N,N`-dimethylethylenediamine  1543.0        M4
# 4                                              XPhos   830.0        M5
#
#                                   metal_name   metal solvent_bin  \
# 0                           copper(l) iodide  8180.0          S1
# 1  tris-(dibenzylideneacetone)dipalladium(0)  6995.0          S2
# 2                        palladium diacetate  4668.0          S3
# 3                                     copper  1875.0          S4
# 4     bis(dibenzylideneacetone)-palladium(0)  1292.0          S5
#
#              solvent_name  solvent
# 0                 toluene  11970.0
# 1             1,4-dioxane   5273.0
# 2  N,N-dimethyl-formamide   4246.0
# 3      dimethyl sulfoxide   3790.0
# 4                   water   2464.0

# %% [markdown]
# ### Plot categorical label distributions

# %%
dict_X = ['metal_bin', 'ligand_bin', 'base_bin', 'solvent_bin', 'additive_bin']
dict_y = ['metal', 'ligand', 'base', 'solvent', 'additive']
dict_bars, dict_ax = plt.subplots(len(dict_X), 1, figsize=(30, 35))
dn = np.arange(len(dict_X))
for X, y, dax, d in zip(dict_X, dict_y, dict_ax, dn):
    sub_df = dict_df[[X, y]]
    sub_df.dropna(how='all', inplace=True)
    dax.bar(sub_df[X], sub_df[y], width=0.9, color=cmap(float(0.95*d)/dn.max()))
    dax.set_xlabel(y, fontsize=16)
    dax.set_ylabel('frequency', fontsize=14)
dict_bars.savefig('cn_dict_bars.png', dpi=300, bbox_inches='tight')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
plt.close(dict_bars)
