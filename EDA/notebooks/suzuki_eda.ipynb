# %% [markdown]
# # Suzuki dataset analysis

# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import QED, Descriptors
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# ### Show shape and features of dataset

# %%
data_df = pd.read_csv('suzuki_full.csv')

# %%
data_df
# Out:
#                                                Reactant 1  \
# 0                COC(=O)C1=CC=CC=C1NC(=O)CCC1=CC=C(I)C=C1
# 1                COC(=O)C1=CC=CC=C1NC(=O)CCC1=CC=C(I)C=C1
# 2                COC(=O)C1=CC=CC=C1NC(=O)CCC1=CC=C(I)C=C1
# 3                COC(=O)C1=CC=CC=C1NC(=O)CCC1=CC=C(I)C=C1
# 4                COC(=O)C1=CC=CC=C1NC(=O)CCC1=CC=C(I)C=C1
# ...                                                   ...
# 145408                               OB(O)C1=C(I)C=CC=C1F
# 145409                 CC1=C2C=C(B(O)O)C(Br)=NC2=C(C)C=C1
# 145410                                  ClC1=NN=C(Cl)N=N1
# 145411  COC1=CC2=C(C3=C1OC(C)(C)C3)C(=NC(C)(C)C2O)C1=C...
# 145412                 OB(O)C1=CC2=C(C=CC=C2)C2=C1C=CC=C2
#
#                         Reactant 2  \
# 0             OCC1=CC=C(C=C1)B(O)O
# 1       OB(O)C1=C(C=CC=C1)C(F)(F)F
# 2               COC1=CC=CC=C1B(O)O
# 3            COC1=CC=C(C=C1F)B(O)O
# 4           COC1=CC=C(C=C1Cl)B(O)O
# ...                            ...
# 145408                        ClCl
# 145409            CC(C)(O)C(C)(C)O
# 145410  CCCCC#CB1OC(C)(C)C(C)(C)O1
# 145411   CC(=O)NC1=CC(=CC=C1)B(O)O
# 145412     FC(F)(F)C1=CC=NC(Br)=C1
#
#                                                   Product  Yield Reagent 1  \
# 0       OCC1=CC=C(C=C1)C1=CC=C(CCC(=O)NC2=CC=CC=C2C(O)...   0.09        S9
# 1       OC(=O)C1=CC=CC=C1NC(=O)CCC1=CC=C(C=C1)C1=CC=CC...   0.07        S9
# 2       COC1=C(C=CC=C1)C1=CC=C(CCC(=O)NC2=C(C=CC=C2)C(...   0.21        S9
# 3       COC1=CC=C(C=C1F)C1=CC=C(CCC(=O)NC2=CC=CC=C2C(O...   0.30        S9
# 4       COC1=CC=C(C=C1Cl)C1=CC=C(CCC(=O)NC2=CC=CC=C2C(...   0.36        S9
# ...                                                   ...    ...       ...
# 145408                       OB(O)C1=C(F)C=CC=C1[I][Cl]Cl   0.90       NaN
# 145409   CC1=C2C=C(B3OC(C)(C)C(C)(C)O3)C(Br)=NC2=C(C)C=C1   0.93       NaN
# 145410         CCCCC1=C(Cl)N=NC(Cl)=C1B1OC(C)(C)C(C)(C)O1   0.14       NaN
# 145411  COC1=CC2=C(C3=C1OC(C)(C)C3)C(=NC(C)(C)C2O)C1=C...   0.64       NaN
# 145412   FC(F)(F)C1=CC(=NC=C1)C1=CC2=CC=CC=C2C2=CC=CC=C12   0.98       NaN
#
#        Reagent 2 Reagent 3 Reagent 4 Reagent 5 Reagent 6 Reagent 7 Reagent 8  \
# 0             M2        B5        L1       NaN       NaN        S4        S2
# 1             M2        B5        L1       NaN       NaN        S4        S2
# 2             M2        B5        L1       NaN       NaN        S4        S2
# 3             M2        B5        L1       NaN       NaN        S4        S2
# 4             M2        B5        L1       NaN       NaN        S4        S2
# ...          ...       ...       ...       ...       ...       ...       ...
# 145408       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 145409       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 145410       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 145411       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 145412       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#        Reagent 9 Reagent 10
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# ...          ...        ...
# 145408       NaN        NaN
# 145409       NaN        NaN
# 145410       NaN        NaN
# 145411       NaN        NaN
# 145412       NaN        NaN
#
# [145413 rows x 14 columns]

# %% [markdown]
# ### Build new dataset for statistical & chemical space analysis

# %%
pdt_df = data_df[['Product', 'Yield']]

# %%
pdt_df
# Out:
#                                                   Product  Yield
# 0       OCC1=CC=C(C=C1)C1=CC=C(CCC(=O)NC2=CC=CC=C2C(O)...   0.09
# 1       OC(=O)C1=CC=CC=C1NC(=O)CCC1=CC=C(C=C1)C1=CC=CC...   0.07
# 2       COC1=C(C=CC=C1)C1=CC=C(CCC(=O)NC2=C(C=CC=C2)C(...   0.21
# 3       COC1=CC=C(C=C1F)C1=CC=C(CCC(=O)NC2=CC=CC=C2C(O...   0.30
# 4       COC1=CC=C(C=C1Cl)C1=CC=C(CCC(=O)NC2=CC=CC=C2C(...   0.36
# ...                                                   ...    ...
# 145408                       OB(O)C1=C(F)C=CC=C1[I][Cl]Cl   0.90
# 145409   CC1=C2C=C(B3OC(C)(C)C(C)(C)O3)C(Br)=NC2=C(C)C=C1   0.93
# 145410         CCCCC1=C(Cl)N=NC(Cl)=C1B1OC(C)(C)C(C)(C)O1   0.14
# 145411  COC1=CC2=C(C3=C1OC(C)(C)C3)C(=NC(C)(C)C2O)C1=C...   0.64
# 145412   FC(F)(F)C1=CC(=NC=C1)C1=CC2=CC=CC=C2C2=CC=CC=C12   0.98
#
# [145413 rows x 2 columns]

# %% [markdown]
# ### Calculate representative molecular descriptors in RDKit
# 16 properties are computed for each SMILES with successful RDKit mol generation.<br>
# Unsuccessful mol generation returns null property vectors.

# %%
MolWt = []
MolLogP = []
TPSA = []
HeavyAtomCount = []
NumHeteroatoms = []
NumValenceElectrons = []
NumHAcceptors = []
NumHDonors = []
NumRotatableBonds = []
RingCount = []
NumAromaticHeterocycles = []
NumAromaticCarbocycles = []
NumSaturatedHeterocycles = []
NumSaturatedCarbocycles = []
FractionCSP3 = []
QED = []

for smi in pdt_df['Product']:
    if not Chem.MolFromSmiles(smi) == None:
        mol = Chem.MolFromSmiles(smi)
        MolWt.append(Descriptors.MolWt(mol))
        MolLogP.append(Descriptors.MolLogP(mol))
        TPSA.append(Descriptors.TPSA(mol))
        HeavyAtomCount.append(Descriptors.HeavyAtomCount(mol))
        NumHeteroatoms.append(Descriptors.NumHeteroatoms(mol))
        NumValenceElectrons.append(Descriptors.NumValenceElectrons(mol))
        NumHAcceptors.append(Descriptors.NumHAcceptors(mol))
        NumHDonors.append(Descriptors.NumHDonors(mol))
        NumRotatableBonds.append(Descriptors.NumRotatableBonds(mol))
        RingCount.append(Descriptors.RingCount(mol))
        NumAromaticHeterocycles.append(Descriptors.NumAromaticHeterocycles(mol))
        NumAromaticCarbocycles.append(Descriptors.NumAromaticCarbocycles(mol))
        NumSaturatedHeterocycles.append(Descriptors.NumSaturatedHeterocycles(mol))
        NumSaturatedCarbocycles.append(Descriptors.NumSaturatedCarbocycles(mol))
        FractionCSP3.append(Descriptors.FractionCSP3(mol))
        QED.append(Chem.QED.default(mol))
    else:
        MolWt.append('')
        MolLogP.append('')
        TPSA.append('')
        HeavyAtomCount.append('')
        NumHeteroatoms.append('')
        NumValenceElectrons.append('')
        NumHAcceptors.append('')
        NumHDonors.append('')
        NumRotatableBonds.append('')
        RingCount.append('')
        NumAromaticHeterocycles.append('')
        NumAromaticCarbocycles.append('')
        NumSaturatedHeterocycles.append('')
        NumSaturatedCarbocycles.append('')
        FractionCSP3.append('')
        QED.append('')

pdt_df['MolWt'] = MolWt
pdt_df['MolLogP'] = MolLogP
pdt_df['TPSA'] = TPSA
pdt_df['HeavyAtomCount'] = HeavyAtomCount
pdt_df['NumHeteroatoms'] = NumHeteroatoms
pdt_df['NumValenceElectrons'] = NumValenceElectrons
pdt_df['NumHAcceptors'] = NumHAcceptors
pdt_df['NumHDonors'] = NumHDonors
pdt_df['NumRotatableBonds'] = NumRotatableBonds
pdt_df['RingCount'] = RingCount
pdt_df['NumAromaticHeterocycles'] = NumAromaticHeterocycles
pdt_df['NumAromaticCarbocycles'] = NumAromaticCarbocycles
pdt_df['NumSaturatedHeterocycles'] = NumSaturatedHeterocycles
pdt_df['NumSaturatedCarbocycles'] = NumSaturatedCarbocycles
pdt_df['FractionCSP3'] = FractionCSP3
pdt_df['QED'] = QED
# Out:
# RDKit ERROR: [13:16:43] Explicit valence for atom # 6 B, 4, is greater than permitted
# RDKit ERROR: [13:16:44] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:16:44] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:16:44] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:16:44] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:16:44] Explicit valence for atom # 19 N, 4, is greater than permitted
# RDKit ERROR: [13:16:48] Explicit valence for atom # 12 B, 4, is greater than permitted
# RDKit ERROR: [13:16:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:16:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:16:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:16:49] Explicit valence for atom # 12 B, 4, is greater than permitted
# RDKit ERROR: [13:16:49] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:16:49] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:16:49] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:16:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:16:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:16:50] Explicit valence for atom # 17 B, 4, is greater than permitted
# RDKit ERROR: [13:16:52] Explicit valence for atom # 12 O, 3, is greater than permitted
# RDKit ERROR: [13:16:52] Explicit valence for atom # 12 O, 3, is greater than permitted
# RDKit ERROR: [13:17:07] Explicit valence for atom # 1 B, 4, is greater than permitted
# RDKit ERROR: [13:17:11] Explicit valence for atom # 10 B, 4, is greater than permitted
# RDKit ERROR: [13:17:26] Explicit valence for atom # 71 N, 4, is greater than permitted
# RDKit ERROR: [13:17:26] Explicit valence for atom # 46 N, 4, is greater than permitted
# RDKit ERROR: [13:17:44] Explicit valence for atom # 3 N, 4, is greater than permitted
# RDKit ERROR: [13:17:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:17:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:17:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:17:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:17:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:17:49] Explicit valence for atom # 13 B, 4, is greater than permitted
# RDKit ERROR: [13:17:49] Explicit valence for atom # 15 B, 4, is greater than permitted
# RDKit ERROR: [13:17:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:17:49] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:18:15] Explicit valence for atom # 1 B, 4, is greater than permitted
# RDKit ERROR: [13:18:20] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:18:20] Explicit valence for atom # 6 C, 5, is greater than permitted
# RDKit ERROR: [13:18:21] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:18:21] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:18:21] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:18:21] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:18:21] Explicit valence for atom # 13 B, 4, is greater than permitted
# RDKit ERROR: [13:18:21] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:18:21] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:18:21] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:18:21] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:18:21] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:18:21] Explicit valence for atom # 5 B, 4, is greater than permitted
# RDKit ERROR: [13:18:21] Explicit valence for atom # 5 B, 4, is greater than permitted
# RDKit ERROR: [13:18:22] Explicit valence for atom # 10 C, 5, is greater than permitted
# RDKit ERROR: [13:18:23] Explicit valence for atom # 4 C, 5, is greater than permitted
# RDKit ERROR: [13:18:23] Explicit valence for atom # 12 B, 4, is greater than permitted
# RDKit ERROR: [13:18:23] Explicit valence for atom # 12 B, 4, is greater than permitted
# RDKit ERROR: [13:18:23] Explicit valence for atom # 7 C, 5, is greater than permitted
# RDKit ERROR: [13:18:27] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:18:27] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:18:39] Explicit valence for atom # 26 N, 4, is greater than permitted
# RDKit ERROR: [13:18:39] Explicit valence for atom # 18 B, 4, is greater than permitted
# RDKit ERROR: [13:18:39] Explicit valence for atom # 19 N, 4, is greater than permitted
# RDKit ERROR: [13:18:39] Explicit valence for atom # 14 N, 4, is greater than permitted
# RDKit ERROR: [13:18:45] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:18:56] Explicit valence for atom # 51 N, 4, is greater than permitted
# RDKit ERROR: [13:18:56] Explicit valence for atom # 22 N, 4, is greater than permitted
# RDKit ERROR: [13:18:56] Explicit valence for atom # 15 N, 4, is greater than permitted
# RDKit ERROR: [13:18:56] Explicit valence for atom # 1 B, 4, is greater than permitted
# RDKit ERROR: [13:18:56] Explicit valence for atom # 11 B, 4, is greater than permitted
# RDKit ERROR: [13:19:08] Explicit valence for atom # 1 B, 4, is greater than permitted
# RDKit ERROR: [13:19:08] Explicit valence for atom # 1 B, 4, is greater than permitted
# RDKit ERROR: [13:19:08] Explicit valence for atom # 1 B, 4, is greater than permitted
# RDKit ERROR: [13:19:09] Explicit valence for atom # 0 F, 2, is greater than permitted
# RDKit ERROR: [13:19:09] Explicit valence for atom # 1 B, 4, is greater than permitted
# RDKit ERROR: [13:19:09] Explicit valence for atom # 2 N, 4, is greater than permitted
# RDKit ERROR: [13:19:10] Explicit valence for atom # 10 N, 4, is greater than permitted
# RDKit ERROR: [13:19:10] Explicit valence for atom # 7 N, 4, is greater than permitted
# RDKit ERROR: [13:19:10] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:19:10] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:19:10] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:19:10] Explicit valence for atom # 8 N, 4, is greater than permitted
# RDKit ERROR: [13:19:11] Explicit valence for atom # 2 N, 4, is greater than permitted
# RDKit ERROR: [13:19:11] Explicit valence for atom # 4 N, 4, is greater than permitted
# RDKit ERROR: [13:19:11] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:19:11] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:19:12] Explicit valence for atom # 10 O, 3, is greater than permitted
# RDKit ERROR: [13:19:15] Explicit valence for atom # 11 N, 4, is greater than permitted
# RDKit ERROR: [13:19:18] Explicit valence for atom # 12 O, 3, is greater than permitted
# RDKit ERROR: [13:19:18] Explicit valence for atom # 12 O, 3, is greater than permitted
# RDKit ERROR: [13:19:21] Explicit valence for atom # 67 O, 3, is greater than permitted
# RDKit ERROR: [13:19:27] Explicit valence for atom # 8 N, 4, is greater than permitted
# RDKit ERROR: [13:19:29] Explicit valence for atom # 31 N, 4, is greater than permitted
# RDKit ERROR: [13:19:29] Explicit valence for atom # 13 N, 4, is greater than permitted
# RDKit ERROR: [13:19:52] Explicit valence for atom # 13 N, 4, is greater than permitted
# RDKit ERROR: [13:19:52] Explicit valence for atom # 1 B, 4, is greater than permitted
# RDKit ERROR: [13:19:52] Explicit valence for atom # 16 B, 4, is greater than permitted
# RDKit ERROR: [13:19:52] Explicit valence for atom # 17 B, 4, is greater than permitted
# RDKit ERROR: [13:19:53] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:19:53] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:19:53] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:19:54] Explicit valence for atom # 20 B, 4, is greater than permitted
# RDKit ERROR: [13:19:54] Explicit valence for atom # 21 B, 4, is greater than permitted
# RDKit ERROR: [13:20:00] Explicit valence for atom # 11 B, 4, is greater than permitted
# RDKit ERROR: [13:20:00] Explicit valence for atom # 11 B, 4, is greater than permitted
# RDKit ERROR: [13:20:00] Explicit valence for atom # 20 N, 4, is greater than permitted
# RDKit ERROR: [13:20:02] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:20:02] Explicit valence for atom # 20 N, 4, is greater than permitted
# RDKit ERROR: [13:20:02] Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [13:20:02] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:20:02] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:20:04] Explicit valence for atom # 12 B, 4, is greater than permitted
# RDKit ERROR: [13:20:10] Explicit valence for atom # 17 B, 4, is greater than permitted
# RDKit ERROR: [13:20:11] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:20:20] Explicit valence for atom # 11 B, 4, is greater than permitted
# RDKit ERROR: [13:20:23] Explicit valence for atom # 13 N, 4, is greater than permitted
# RDKit ERROR: [13:20:31] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:20:31] Explicit valence for atom # 15 B, 4, is greater than permitted
# RDKit ERROR: [13:20:31] Explicit valence for atom # 10 N, 4, is greater than permitted
# RDKit ERROR: [13:20:32] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:20:32] Explicit valence for atom # 8 O, 3, is greater than permitted
# RDKit ERROR: [13:20:32] Explicit valence for atom # 15 B, 4, is greater than permitted
# RDKit ERROR: [13:20:32] Explicit valence for atom # 10 N, 4, is greater than permitted
# RDKit ERROR: [13:20:32] Explicit valence for atom # 18 N, 4, is greater than permitted
# RDKit ERROR: [13:20:33] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:20:34] Explicit valence for atom # 15 N, 4, is greater than permitted
# RDKit ERROR: [13:20:36] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:20:36] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:20:36] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:20:40] Explicit valence for atom # 16 N, 5, is greater than permitted
# RDKit ERROR: [13:20:40] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:20:40] Explicit valence for atom # 13 N, 5, is greater than permitted
# RDKit ERROR: [13:20:40] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:20:40] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:20:40] Explicit valence for atom # 14 N, 5, is greater than permitted
# RDKit ERROR: [13:20:40] Explicit valence for atom # 10 N, 5, is greater than permitted
# RDKit ERROR: [13:20:41] Explicit valence for atom # 18 N, 5, is greater than permitted
# RDKit ERROR: [13:20:41] Explicit valence for atom # 15 N, 5, is greater than permitted
# RDKit ERROR: [13:20:41] Explicit valence for atom # 6 N, 5, is greater than permitted
# RDKit ERROR: [13:20:41] Explicit valence for atom # 16 N, 5, is greater than permitted
# RDKit ERROR: [13:20:42] Explicit valence for atom # 13 N, 5, is greater than permitted
# RDKit ERROR: [13:20:42] Explicit valence for atom # 15 N, 5, is greater than permitted
# RDKit ERROR: [13:20:43] Explicit valence for atom # 16 N, 5, is greater than permitted
# RDKit ERROR: [13:20:43] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:20:43] Explicit valence for atom # 13 N, 5, is greater than permitted
# RDKit ERROR: [13:20:43] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:20:43] Explicit valence for atom # 16 N, 5, is greater than permitted
# RDKit ERROR: [13:20:43] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:20:43] Explicit valence for atom # 15 N, 5, is greater than permitted
# RDKit ERROR: [13:20:43] Explicit valence for atom # 13 N, 5, is greater than permitted
# RDKit ERROR: [13:20:43] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:20:46] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:20:48] Explicit valence for atom # 41 B, 4, is greater than permitted
# RDKit ERROR: [13:20:48] Explicit valence for atom # 20 B, 4, is greater than permitted
# RDKit ERROR: [13:20:50] Explicit valence for atom # 48 N, 4, is greater than permitted
# RDKit ERROR: [13:20:50] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:20:50] Explicit valence for atom # 38 N, 4, is greater than permitted
# RDKit ERROR: [13:20:50] Explicit valence for atom # 43 N, 4, is greater than permitted
# RDKit ERROR: [13:20:50] Explicit valence for atom # 53 N, 4, is greater than permitted
# RDKit ERROR: [13:20:50] Explicit valence for atom # 50 N, 4, is greater than permitted
# RDKit ERROR: [13:20:50] Explicit valence for atom # 60 N, 4, is greater than permitted
# RDKit ERROR: [13:20:51] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:20:55] Explicit valence for atom # 13 B, 4, is greater than permitted
# RDKit ERROR: [13:20:55] Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [13:20:55] Explicit valence for atom # 13 B, 4, is greater than permitted
# RDKit ERROR: [13:20:55] Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [13:20:55] Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [13:20:55] Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [13:20:55] Explicit valence for atom # 40 B, 4, is greater than permitted
# RDKit ERROR: [13:20:55] Explicit valence for atom # 40 B, 4, is greater than permitted
# RDKit ERROR: [13:20:55] Explicit valence for atom # 40 B, 4, is greater than permitted
# RDKit ERROR: [13:20:55] Explicit valence for atom # 40 B, 4, is greater than permitted
# RDKit ERROR: [13:20:55] Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [13:20:55] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:20:55] Explicit valence for atom # 8 N, 4, is greater than permitted
# RDKit ERROR: [13:20:56] Explicit valence for atom # 1 B, 4, is greater than permitted
# RDKit ERROR: [13:20:56] Explicit valence for atom # 1 B, 4, is greater than permitted
# RDKit ERROR: [13:20:57] Explicit valence for atom # 40 B, 4, is greater than permitted
# RDKit ERROR: [13:20:57] Explicit valence for atom # 46 B, 4, is greater than permitted
# RDKit ERROR: [13:20:57] Explicit valence for atom # 35 B, 4, is greater than permitted
# RDKit ERROR: [13:20:57] Explicit valence for atom # 34 B, 4, is greater than permitted
# RDKit ERROR: [13:20:57] Explicit valence for atom # 20 N, 4, is greater than permitted
# RDKit ERROR: [13:20:57] Explicit valence for atom # 20 N, 4, is greater than permitted
# RDKit ERROR: [13:20:58] Explicit valence for atom # 36 B, 4, is greater than permitted
# RDKit ERROR: [13:20:58] Explicit valence for atom # 25 B, 4, is greater than permitted
# RDKit ERROR: [13:20:58] Explicit valence for atom # 13 B, 4, is greater than permitted
# RDKit ERROR: [13:20:58] Explicit valence for atom # 32 B, 4, is greater than permitted
# RDKit ERROR: [13:20:58] Explicit valence for atom # 1 B, 4, is greater than permitted
# RDKit ERROR: [13:20:58] Explicit valence for atom # 46 B, 4, is greater than permitted
# RDKit ERROR: [13:20:58] Explicit valence for atom # 1 B, 4, is greater than permitted
# RDKit ERROR: [13:20:58] Explicit valence for atom # 1 B, 4, is greater than permitted
# RDKit ERROR: [13:21:02] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:21:02] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:21:02] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:21:02] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:21:04] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:21:10] Explicit valence for atom # 8 N, 5, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 13 B, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 13 B, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 15 B, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 13 B, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 9 O, 3, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:11] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:12] Explicit valence for atom # 5 B, 4, is greater than permitted
# RDKit ERROR: [13:21:12] Explicit valence for atom # 5 B, 4, is greater than permitted
# RDKit ERROR: [13:21:12] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:21:12] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:21:12] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:21:12] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:21:12] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:21:13] Explicit valence for atom # 8 B, 4, is greater than permitted
# RDKit ERROR: [13:21:13] Explicit valence for atom # 14 N, 4, is greater than permitted
# RDKit ERROR: [13:21:13] Explicit valence for atom # 1 B, 4, is greater than permitted
# RDKit ERROR: [13:21:13] Explicit valence for atom # 1 B, 4, is greater than permitted
# RDKit ERROR: [13:21:13] Explicit valence for atom # 10 N, 4, is greater than permitted
# RDKit ERROR: [13:21:13] Explicit valence for atom # 9 N, 4, is greater than permitted
# RDKit ERROR: [13:21:16] Explicit valence for atom # 14 B, 4, is greater than permitted
# RDKit ERROR: [13:21:16] Explicit valence for atom # 24 N, 4, is greater than permitted
# RDKit ERROR: [13:21:17] Explicit valence for atom # 16 C, 5, is greater than permitted
# RDKit ERROR: [13:21:18] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:18] Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [13:21:19] Explicit valence for atom # 16 N, 4, is greater than permitted
# RDKit ERROR: [13:21:27] Explicit valence for atom # 8 Cl, 2, is greater than permitted
# RDKit ERROR: [13:21:28] Explicit valence for atom # 22 C, 6, is greater than permitted
# RDKit ERROR: [13:21:28] Explicit valence for atom # 21 B, 4, is greater than permitted
# RDKit ERROR: [13:21:43] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:21:44] Explicit valence for atom # 14 N, 5, is greater than permitted
# RDKit ERROR: [13:21:44] Explicit valence for atom # 14 N, 5, is greater than permitted
# RDKit ERROR: [13:21:44] Explicit valence for atom # 3 N, 5, is greater than permitted
# RDKit ERROR: [13:21:44] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:21:44] Explicit valence for atom # 3 N, 5, is greater than permitted
# RDKit ERROR: [13:21:44] Explicit valence for atom # 3 N, 5, is greater than permitted
# RDKit ERROR: [13:21:44] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:21:44] Explicit valence for atom # 13 N, 5, is greater than permitted
# RDKit ERROR: [13:21:44] Explicit valence for atom # 7 N, 5, is greater than permitted
# RDKit ERROR: [13:21:44] Explicit valence for atom # 7 N, 5, is greater than permitted
# RDKit ERROR: [13:21:44] Explicit valence for atom # 13 N, 5, is greater than permitted
# RDKit ERROR: [13:21:44] Explicit valence for atom # 13 N, 5, is greater than permitted
# RDKit ERROR: [13:21:44] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:21:44] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:21:46] Explicit valence for atom # 14 Cl, 2, is greater than permitted
# RDKit ERROR: [13:21:46] Explicit valence for atom # 10 B, 4, is greater than permitted
# RDKit ERROR: [13:21:46] Explicit valence for atom # 14 B, 4, is greater than permitted
# RDKit ERROR: [13:21:47] Explicit valence for atom # 8 Br, 2, is greater than permitted
# RDKit ERROR: [13:21:48] Explicit valence for atom # 17 B, 4, is greater than permitted
# RDKit ERROR: [13:21:48] Explicit valence for atom # 27 B, 4, is greater than permitted
# RDKit ERROR: [13:21:48] Explicit valence for atom # 23 B, 4, is greater than permitted
# RDKit ERROR: [13:21:48] Explicit valence for atom # 25 B, 4, is greater than permitted
# RDKit ERROR: [13:21:48] Explicit valence for atom # 24 B, 4, is greater than permitted
# RDKit ERROR: [13:21:48] Explicit valence for atom # 24 B, 4, is greater than permitted
# RDKit ERROR: [13:21:48] Explicit valence for atom # 24 B, 4, is greater than permitted
# RDKit ERROR: [13:21:48] Explicit valence for atom # 27 B, 4, is greater than permitted
# RDKit ERROR: [13:21:48] Explicit valence for atom # 19 B, 4, is greater than permitted
# RDKit ERROR: [13:21:48] Explicit valence for atom # 19 B, 4, is greater than permitted
# RDKit ERROR: [13:21:48] Explicit valence for atom # 20 B, 4, is greater than permitted
# RDKit ERROR: [13:21:48] Explicit valence for atom # 22 B, 4, is greater than permitted
# RDKit ERROR: [13:21:48] Explicit valence for atom # 18 B, 4, is greater than permitted
# RDKit ERROR: [13:21:48] Explicit valence for atom # 18 B, 4, is greater than permitted
# RDKit ERROR: [13:21:48] Explicit valence for atom # 20 B, 4, is greater than permitted
# RDKit ERROR: [13:21:51] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:51] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:51] Explicit valence for atom # 10 B, 4, is greater than permitted
# RDKit ERROR: [13:21:51] Explicit valence for atom # 12 B, 4, is greater than permitted
# RDKit ERROR: [13:21:53] Explicit valence for atom # 13 B, 4, is greater than permitted
# RDKit ERROR: [13:21:53] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:21:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:53] Explicit valence for atom # 20 B, 4, is greater than permitted
# RDKit ERROR: [13:21:53] Explicit valence for atom # 11 B, 4, is greater than permitted
# RDKit ERROR: [13:21:53] Explicit valence for atom # 17 B, 4, is greater than permitted
# RDKit ERROR: [13:21:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:21:56] Explicit valence for atom # 13 B, 4, is greater than permitted
# RDKit ERROR: [13:21:56] Explicit valence for atom # 18 B, 4, is greater than permitted
# RDKit ERROR: [13:21:58] Explicit valence for atom # 0 O, 3, is greater than permitted
# RDKit ERROR: [13:21:58] Explicit valence for atom # 14 B, 4, is greater than permitted
# RDKit ERROR: [13:21:58] Explicit valence for atom # 18 B, 4, is greater than permitted
# RDKit ERROR: [13:21:59] Explicit valence for atom # 14 B, 4, is greater than permitted
# RDKit ERROR: [13:22:01] Explicit valence for atom # 24 B, 4, is greater than permitted
# RDKit ERROR: [13:22:04] Explicit valence for atom # 9 N, 4, is greater than permitted
# RDKit ERROR: [13:22:04] Explicit valence for atom # 9 N, 4, is greater than permitted
# RDKit ERROR: [13:22:13] Explicit valence for atom # 6 N, 4, is greater than permitted
# RDKit ERROR: [13:22:14] Explicit valence for atom # 4 N, 4, is greater than permitted
# RDKit ERROR: [13:22:19] Explicit valence for atom # 19 N, 4, is greater than permitted
# RDKit ERROR: [13:22:28] Explicit valence for atom # 7 C, 5, is greater than permitted
# RDKit ERROR: [13:22:31] Explicit valence for atom # 9 C, 5, is greater than permitted
# RDKit ERROR: [13:22:31] Explicit valence for atom # 4 C, 5, is greater than permitted
# RDKit ERROR: [13:22:33] Explicit valence for atom # 4 C, 5, is greater than permitted
# RDKit ERROR: [13:22:34] Explicit valence for atom # 12 B, 4, is greater than permitted
# RDKit ERROR: [13:22:34] Explicit valence for atom # 7 C, 5, is greater than permitted
# RDKit ERROR: [13:22:34] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:22:38] Explicit valence for atom # 1 B, 5, is greater than permitted
# RDKit ERROR: [13:22:38] Explicit valence for atom # 22 N, 5, is greater than permitted
# RDKit ERROR: [13:23:05] Explicit valence for atom # 3 N, 4, is greater than permitted
# RDKit ERROR: [13:23:05] Explicit valence for atom # 3 N, 4, is greater than permitted
# RDKit ERROR: [13:23:05] Explicit valence for atom # 3 N, 4, is greater than permitted
# RDKit ERROR: [13:23:24] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:23:24] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:23:24] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:23:24] Explicit valence for atom # 5 N, 4, is greater than permitted
# RDKit ERROR: [13:23:31] Explicit valence for atom # 20 B, 4, is greater than permitted
# RDKit ERROR: [13:23:32] Explicit valence for atom # 2 N, 4, is greater than permitted
# RDKit ERROR: [13:23:32] Explicit valence for atom # 2 N, 4, is greater than permitted
# RDKit ERROR: [13:23:32] Explicit valence for atom # 16 B, 4, is greater than permitted
# RDKit ERROR: [13:23:32] Explicit valence for atom # 2 N, 4, is greater than permitted
# RDKit ERROR: [13:23:32] Explicit valence for atom # 2 N, 4, is greater than permitted
# RDKit ERROR: [13:23:32] Explicit valence for atom # 2 N, 4, is greater than permitted
# RDKit ERROR: [13:23:32] Explicit valence for atom # 2 N, 4, is greater than permitted
# RDKit ERROR: [13:23:32] Explicit valence for atom # 2 N, 4, is greater than permitted
# RDKit ERROR: [13:23:32] Explicit valence for atom # 2 N, 4, is greater than permitted
# RDKit ERROR: [13:23:32] Explicit valence for atom # 12 B, 4, is greater than permitted
# RDKit ERROR: [13:23:49] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:23:49] Explicit valence for atom # 20 N, 5, is greater than permitted
# RDKit ERROR: [13:23:49] Explicit valence for atom # 20 N, 5, is greater than permitted
# RDKit ERROR: [13:23:49] Explicit valence for atom # 16 N, 5, is greater than permitted
# RDKit ERROR: [13:23:49] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:23:49] Explicit valence for atom # 9 N, 5, is greater than permitted
# RDKit ERROR: [13:23:49] Explicit valence for atom # 9 N, 5, is greater than permitted
# RDKit ERROR: [13:23:49] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:23:49] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:23:49] Explicit valence for atom # 17 N, 5, is greater than permitted
# RDKit ERROR: [13:23:49] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:23:49] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 18 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 22 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 19 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 3 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 7 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 13 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 14 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 15 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 15 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 14 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 14 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 13 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 13 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 14 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 13 N, 5, is greater than permitted
# RDKit ERROR: [13:23:50] Explicit valence for atom # 14 N, 5, is greater than permitted
# RDKit ERROR: [13:24:00] Explicit valence for atom # 8 Br, 2, is greater than permitted
# RDKit ERROR: [13:24:01] Explicit valence for atom # 12 Cl, 2, is greater than permitted
# RDKit ERROR: [13:24:16] Explicit valence for atom # 7 N, 4, is greater than permitted
# RDKit ERROR: [13:24:16] Explicit valence for atom # 10 C, 5, is greater than permitted
# RDKit ERROR: [13:24:19] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:24:19] Explicit valence for atom # 14 B, 4, is greater than permitted
# RDKit ERROR: [13:24:19] Explicit valence for atom # 13 B, 4, is greater than permitted
# RDKit ERROR: [13:24:19] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:24:19] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:24:19] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:24:19] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:24:20] Explicit valence for atom # 2 B, 4, is greater than permitted
# RDKit ERROR: [13:24:21] Explicit valence for atom # 23 C, 5, is greater than permitted
# RDKit ERROR: [13:24:21] Explicit valence for atom # 10 O, 3, is greater than permitted
# RDKit ERROR: [13:24:22] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:24:22] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:24:22] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:24:22] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:24:22] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:24:22] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:24:22] Explicit valence for atom # 7 B, 4, is greater than permitted
# RDKit ERROR: [13:24:22] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:24:22] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:24:22] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:24:22] Explicit valence for atom # 9 B, 4, is greater than permitted
# RDKit ERROR: [13:24:23] Explicit valence for atom # 3 N, 4, is greater than permitted
# RDKit ERROR: [13:24:25] Explicit valence for atom # 4 N, 4, is greater than permitted
# RDKit ERROR: [13:24:25] Explicit valence for atom # 4 N, 4, is greater than permitted
# RDKit ERROR: [13:24:25] Explicit valence for atom # 18 B, 4, is greater than permitted
# RDKit ERROR: [13:24:25] Explicit valence for atom # 13 B, 4, is greater than permitted
# RDKit ERROR: [13:24:25] Explicit valence for atom # 18 B, 4, is greater than permitted
# RDKit ERROR: [13:24:25] Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [13:24:25] Explicit valence for atom # 12 N, 4, is greater than permitted
# RDKit ERROR: [13:24:25] Explicit valence for atom # 6 N, 4, is greater than permitted
# RDKit ERROR: [13:24:25] Explicit valence for atom # 5 O, 3, is greater than permitted
# RDKit ERROR: [13:24:26] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:24:26] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:24:26] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:24:26] Explicit valence for atom # 19 N, 5, is greater than permitted
# RDKit ERROR: [13:24:26] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:24:26] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:24:26] Explicit valence for atom # 11 N, 5, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 15 B, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 19 B, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 15 B, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 13 B, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 4 B, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 13 B, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 11 B, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 2 B, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 26 B, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 18 B, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 20 B, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 31 B, 4, is greater than permitted
# RDKit ERROR: [13:24:29] Explicit valence for atom # 5 B, 4, is greater than permitted
# RDKit ERROR: [13:24:30] Explicit valence for atom # 13 B, 4, is greater than permitted
# RDKit ERROR: [13:24:32] Explicit valence for atom # 12 B, 4, is greater than permitted
# RDKit ERROR: [13:24:41] Explicit valence for atom # 56 B, 4, is greater than permitted
# RDKit ERROR: [13:24:50] Explicit valence for atom # 4 N, 5, is greater than permitted
# RDKit ERROR: [13:24:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# RDKit ERROR: [13:24:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# RDKit ERROR: [13:24:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# RDKit ERROR: [13:24:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# RDKit ERROR: [13:24:50] Explicit valence for atom # 1 N, 4, is greater than permitted
# RDKit ERROR: [13:24:50] Explicit valence for atom # 4 N, 5, is greater than permitted
# RDKit ERROR: [13:24:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# RDKit ERROR: [13:24:50] Explicit valence for atom # 4 N, 4, is greater than permitted
# RDKit ERROR: [13:24:50] Explicit valence for atom # 11 Cl, 2, is greater than permitted
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
pdt_df
# Out:
#                                                   Product  Yield    MolWt  \
# 0       OCC1=CC=C(C=C1)C1=CC=C(CCC(=O)NC2=CC=CC=C2C(O)...   0.09  375.424
# 1       OC(=O)C1=CC=CC=C1NC(=O)CCC1=CC=C(C=C1)C1=CC=CC...   0.07  413.395
# 2       COC1=C(C=CC=C1)C1=CC=C(CCC(=O)NC2=C(C=CC=C2)C(...   0.21  375.424
# 3       COC1=CC=C(C=C1F)C1=CC=C(CCC(=O)NC2=CC=CC=C2C(O...   0.30  393.414
# 4       COC1=CC=C(C=C1Cl)C1=CC=C(CCC(=O)NC2=CC=CC=C2C(...   0.36  409.869
# ...                                                   ...    ...      ...
# 145408                       OB(O)C1=C(F)C=CC=C1[I][Cl]Cl   0.90
# 145409   CC1=C2C=C(B3OC(C)(C)C(C)(C)O3)C(Br)=NC2=C(C)C=C1   0.93  362.076
# 145410         CCCCC1=C(Cl)N=NC(Cl)=C1B1OC(C)(C)C(C)(C)O1   0.14  331.052
# 145411  COC1=CC2=C(C3=C1OC(C)(C)C3)C(=NC(C)(C)C2O)C1=C...   0.64  484.596
# 145412   FC(F)(F)C1=CC(=NC=C1)C1=CC2=CC=CC=C2C2=CC=CC=C12   0.98  323.317
#
#         MolLogP   TPSA HeavyAtomCount NumHeteroatoms NumValenceElectrons  \
# 0        4.1154  86.63             28              5                 142
# 1        5.6419   66.4             30              7                 154
# 2        4.6317  75.63             28              5                 142
# 3        4.7708  75.63             29              6                 148
# 4        5.2851  75.63             29              6                 148
# ...         ...    ...            ...            ...                 ...
# 145408
# 145409  3.91334  31.35             22              5                 116
# 145410   3.4252  44.24             21              7                 116
# 145411   5.6971  80.15             36              6                 186
# 145412   6.0738  12.89             24              4                 118
#
#        NumHAcceptors NumHDonors NumRotatableBonds RingCount  \
# 0                  3          3                 7         3
# 1                  2          2                 6         3
# 2                  3          2                 7         3
# 3                  3          2                 7         3
# 4                  3          2                 7         3
# ...              ...        ...               ...       ...
# 145408
# 145409             3          0                 1         3
# 145410             4          0                 4         2
# 145411             5          2                 4         5
# 145412             1          0                 1         4
#
#        NumAromaticHeterocycles NumAromaticCarbocycles  \
# 0                            0                      3
# 1                            0                      3
# 2                            0                      3
# 3                            0                      3
# 4                            0                      3
# ...                        ...                    ...
# 145408
# 145409                       1                      1
# 145410                       1                      0
# 145411                       0                      3
# 145412                       1                      3
#
#        NumSaturatedHeterocycles NumSaturatedCarbocycles FractionCSP3       QED
# 0                             0                       0     0.130435  0.579829
# 1                             0                       0     0.130435  0.549483
# 2                             0                       0     0.130435  0.631163
# 3                             0                       0     0.130435  0.606249
# 4                             0                       0     0.130435   0.55588
# ...                         ...                     ...          ...       ...
# 145408
# 145409                        1                       0     0.470588  0.569537
# 145410                        1                       0     0.714286   0.79327
# 145411                        0                       0     0.333333  0.498063
# 145412                        0                       0         0.05  0.387173
#
# [145413 rows x 18 columns]

# %% [markdown]
# ### Convert property vector dtypes to float64

# %%
pdt_df.dtypes
# Out:
# Product                      object
# Yield                       float64
# MolWt                        object
# MolLogP                      object
# TPSA                         object
# HeavyAtomCount               object
# NumHeteroatoms               object
# NumValenceElectrons          object
# NumHAcceptors                object
# NumHDonors                   object
# NumRotatableBonds            object
# RingCount                    object
# NumAromaticHeterocycles      object
# NumAromaticCarbocycles       object
# NumSaturatedHeterocycles     object
# NumSaturatedCarbocycles      object
# FractionCSP3                 object
# QED                          object
# dtype: object

# %%
cols = list(pdt_df.columns)

# %%
cols.pop(0)
# Out:
# 'Product'

# %%
pdt_df[cols] = pdt_df[cols].apply(pd.to_numeric, errors='coerce')

# %%
pdt_df.dtypes
# Out:
# Product                      object
# Yield                       float64
# MolWt                       float64
# MolLogP                     float64
# TPSA                        float64
# HeavyAtomCount              float64
# NumHeteroatoms              float64
# NumValenceElectrons         float64
# NumHAcceptors               float64
# NumHDonors                  float64
# NumRotatableBonds           float64
# RingCount                   float64
# NumAromaticHeterocycles     float64
# NumAromaticCarbocycles      float64
# NumSaturatedHeterocycles    float64
# NumSaturatedCarbocycles     float64
# FractionCSP3                float64
# QED                         float64
# dtype: object

# %%
pdt_df
# Out:
#                                                   Product  Yield    MolWt  \
# 0       OCC1=CC=C(C=C1)C1=CC=C(CCC(=O)NC2=CC=CC=C2C(O)...   0.09  375.424
# 1       OC(=O)C1=CC=CC=C1NC(=O)CCC1=CC=C(C=C1)C1=CC=CC...   0.07  413.395
# 2       COC1=C(C=CC=C1)C1=CC=C(CCC(=O)NC2=C(C=CC=C2)C(...   0.21  375.424
# 3       COC1=CC=C(C=C1F)C1=CC=C(CCC(=O)NC2=CC=CC=C2C(O...   0.30  393.414
# 4       COC1=CC=C(C=C1Cl)C1=CC=C(CCC(=O)NC2=CC=CC=C2C(...   0.36  409.869
# ...                                                   ...    ...      ...
# 145408                       OB(O)C1=C(F)C=CC=C1[I][Cl]Cl   0.90      NaN
# 145409   CC1=C2C=C(B3OC(C)(C)C(C)(C)O3)C(Br)=NC2=C(C)C=C1   0.93  362.076
# 145410         CCCCC1=C(Cl)N=NC(Cl)=C1B1OC(C)(C)C(C)(C)O1   0.14  331.052
# 145411  COC1=CC2=C(C3=C1OC(C)(C)C3)C(=NC(C)(C)C2O)C1=C...   0.64  484.596
# 145412   FC(F)(F)C1=CC(=NC=C1)C1=CC2=CC=CC=C2C2=CC=CC=C12   0.98  323.317
#
#         MolLogP   TPSA  HeavyAtomCount  NumHeteroatoms  NumValenceElectrons  \
# 0       4.11540  86.63            28.0             5.0                142.0
# 1       5.64190  66.40            30.0             7.0                154.0
# 2       4.63170  75.63            28.0             5.0                142.0
# 3       4.77080  75.63            29.0             6.0                148.0
# 4       5.28510  75.63            29.0             6.0                148.0
# ...         ...    ...             ...             ...                  ...
# 145408      NaN    NaN             NaN             NaN                  NaN
# 145409  3.91334  31.35            22.0             5.0                116.0
# 145410  3.42520  44.24            21.0             7.0                116.0
# 145411  5.69710  80.15            36.0             6.0                186.0
# 145412  6.07380  12.89            24.0             4.0                118.0
#
#         NumHAcceptors  NumHDonors  NumRotatableBonds  RingCount  \
# 0                 3.0         3.0                7.0        3.0
# 1                 2.0         2.0                6.0        3.0
# 2                 3.0         2.0                7.0        3.0
# 3                 3.0         2.0                7.0        3.0
# 4                 3.0         2.0                7.0        3.0
# ...               ...         ...                ...        ...
# 145408            NaN         NaN                NaN        NaN
# 145409            3.0         0.0                1.0        3.0
# 145410            4.0         0.0                4.0        2.0
# 145411            5.0         2.0                4.0        5.0
# 145412            1.0         0.0                1.0        4.0
#
#         NumAromaticHeterocycles  NumAromaticCarbocycles  \
# 0                           0.0                     3.0
# 1                           0.0                     3.0
# 2                           0.0                     3.0
# 3                           0.0                     3.0
# 4                           0.0                     3.0
# ...                         ...                     ...
# 145408                      NaN                     NaN
# 145409                      1.0                     1.0
# 145410                      1.0                     0.0
# 145411                      0.0                     3.0
# 145412                      1.0                     3.0
#
#         NumSaturatedHeterocycles  NumSaturatedCarbocycles  FractionCSP3  \
# 0                            0.0                      0.0      0.130435
# 1                            0.0                      0.0      0.130435
# 2                            0.0                      0.0      0.130435
# 3                            0.0                      0.0      0.130435
# 4                            0.0                      0.0      0.130435
# ...                          ...                      ...           ...
# 145408                       NaN                      NaN           NaN
# 145409                       1.0                      0.0      0.470588
# 145410                       1.0                      0.0      0.714286
# 145411                       0.0                      0.0      0.333333
# 145412                       0.0                      0.0      0.050000
#
#              QED
# 0       0.579829
# 1       0.549483
# 2       0.631163
# 3       0.606249
# 4       0.555880
# ...          ...
# 145408       NaN
# 145409  0.569537
# 145410  0.793270
# 145411  0.498063
# 145412  0.387173
#
# [145413 rows x 18 columns]

# %% [markdown]
# ## Property vector statistical analysis

# %%
stats = pdt_df.describe().round(decimals=3)
stats.to_csv('suzuki_stats.csv', float_format='%g')
stats
# Out:
#             Yield       MolWt     MolLogP        TPSA  HeavyAtomCount  \
# count  145413.000  144972.000  144972.000  144972.000      144972.000
# mean        0.682     352.072       4.704      49.805          25.323
# std         0.237     146.421       2.258      36.775          10.435
# min         0.000      82.106      -5.969       0.000           6.000
# 25%         0.530     233.227       3.354      20.230          17.000
# 50%         0.730     331.757       4.142      43.600          24.000
# 75%         0.880     438.444       5.519      72.450          31.000
# max         1.000    2339.164      46.845     472.090         164.000
#
#        NumHeteroatoms  NumValenceElectrons  NumHAcceptors  NumHDonors  \
# count      144972.000           144972.000     144972.000  144972.000
# mean            4.938              129.042          3.622       0.525
# std             3.421               54.925          2.589       0.832
# min             0.000               32.000          0.000       0.000
# 25%             2.000               84.000          2.000       0.000
# 50%             4.000              120.000          3.000       0.000
# 75%             7.000              160.000          5.000       1.000
# max            86.000              952.000         39.000      16.000
#
#        NumRotatableBonds   RingCount  NumAromaticHeterocycles  \
# count         144972.000  144972.000               144972.000
# mean               3.968       3.472                    1.028
# std                3.483       1.639                    1.050
# min                0.000       0.000                    0.000
# 25%                2.000       2.000                    0.000
# 50%                3.000       3.000                    1.000
# 75%                5.000       4.000                    2.000
# max              115.000      11.000                    8.000
#
#        NumAromaticCarbocycles  NumSaturatedHeterocycles  \
# count              144972.000                144972.000
# mean                    1.976                     0.171
# std                     1.248                     0.450
# min                     0.000                     0.000
# 25%                     1.000                     0.000
# 50%                     2.000                     0.000
# 75%                     2.000                     0.000
# max                     9.000                     7.000
#
#        NumSaturatedCarbocycles  FractionCSP3         QED
# count               144972.000    144972.000  144972.000
# mean                     0.097         0.188       0.544
# std                      0.394         0.166       0.201
# min                      0.000         0.000       0.008
# 25%                      0.000         0.067       0.396
# 50%                      0.000         0.143       0.591
# 75%                      0.000         0.300       0.695
# max                      5.000         1.000       0.948

# %% [markdown]
# ## Plot yield distribution
# Note 'ax.hist' can be replaced with 'ax.kde' for kernel density estimation

# %%
yield_hist, ax = plt.subplots(figsize=(5, 5))
ax.hist(pdt_df['Yield'], bins=20, rwidth=0.9, color=plt.get_cmap('winter')(0.27))
ax.set_xlabel('yield')
ax.set_ylabel('frequency')
yield_hist.savefig('suzuki_yield_hist.png', dpi=300, bbox_inches='tight')

# %%
plt.close(yield_hist)

# %% [markdown]
# ## Plot descriptor distributions
# Again, 'axis.hist' can be replaced with 'axis.kde'

# %%
props = pdt_df.drop(['Product', 'Yield'], axis=1)

# %%
prop_hists, axes = plt.subplots(4, 4, figsize=(20, 20))
cmap = plt.get_cmap('winter')
kn = np.arange(len(props.columns))
for col, axis, k in zip(props.columns, axes.flatten(), kn):
    series = props[col]
    #removing outliers to avoid sparse tail distribution
    data = series[series.between(series.quantile(.01), series.quantile(.99))]
    axis.hist(data, rwidth=0.9, color=cmap(float(0.95*k)/kn.max()))
    axis.set_xlabel(col, fontsize=12)
    if (k+1)%4 == 1%4:
        axis.set_ylabel('frequency')
prop_hists.savefig('suzuki_prop_hists.png', dpi=300, bbox_inches='tight')

# %%
plt.close(prop_hists)

# %% [markdown]
# # Suzuki dictionary analysis

# %%
dict_df = pd.read_csv('suzuki_dict_final.csv')
dict_df.head()
# Out:
#                                           metal_name metal_bin    metal  \
# 0          tetrakis(triphenylphosphine) palladium(0)        M1  55829.0
# 1                                palladium diacetate        M2  16927.0
# 2  (1,1'-bis(diphenylphosphino)ferrocene)palladiu...        M3  13723.0
# 3  dichloro(1,1'-bis(diphenylphosphanyl)ferrocene...        M4   8918.0
# 4      bis-triphenylphosphine-palladium(II) chloride        M5   8761.0
#
#                                          ligand_name ligand_bin  ligand  \
# 0                                 triphenylphosphine         L1  4489.0
# 1  dicyclohexyl-(2',6'-dimethoxybiphenyl-2-yl)-ph...         L2  3163.0
# 2                                              XPhos         L3  2100.0
# 3                             tricyclohexylphosphine         L4  1808.0
# 4                            tris-(o-tolyl)phosphine         L5   902.0
#
#                   base_name base_bin   base         solvent_name solvent_bin  \
# 0       potassium carbonate       B1  48981      tetrahydrofuran          S1
# 1          sodium carbonate       B2  39769              ethanol          S2
# 2       potassium phosphate       B3  17799             methanol          S3
# 3         caesium carbonate       B4  13345          1,4-dioxane          S4
# 4  sodium hydrogencarbonate       B5   3722  1,2-dimethoxyethane          S5
#
#    solvent               additive_name additive_bin  additive
# 0  18113.0  tetrabutylammomium bromide           A1    3003.0
# 1  24836.0                       water           A2    1606.0
# 2   4374.0            lithium chloride           A3     819.0
# 3  39107.0            hydrogenchloride           A4     780.0
# 4  19131.0            copper(l) iodide           A5     546.0

# %% [markdown]
# ### Plot categorical label distributions

# %%
dict_X = ['metal_bin', 'ligand_bin', 'base_bin', 'solvent_bin', 'additive_bin']
dict_y = ['metal', 'ligand', 'base', 'solvent', 'additive']
dict_bars, dict_ax = plt.subplots(len(dict_X), 1, figsize=(20, 25))
dn = np.arange(len(dict_X))
for X, y, dax, d in zip(dict_X, dict_y, dict_ax, dn):
    sub_df = dict_df[[X, y]]
    sub_df.dropna(how='all', inplace=True)
    dax.bar(sub_df[X], sub_df[y], width=0.9, color=cmap(float(0.95*d)/dn.max()))
    dax.set_xlabel(y, fontsize=16)
    dax.set_ylabel('frequency', fontsize=14)
dict_bars.savefig('suzuki_dict_bars.png', dpi=300, bbox_inches='tight')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
plt.close(dict_bars)
