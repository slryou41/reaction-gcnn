# %% [markdown]
# # Negishi dataset analysis

# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import QED, Descriptors
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# ### Show shape and features of dataset

# %%
data_df = pd.read_csv('negishi_full.csv')

# %%
data_df
# Out:
#       Reaction ID                                         References  \
# 0        31881337  Article; Ichikawa, Musubu; Wakabayashi, Kenta;...
# 1        31881339  Article; Ichikawa, Musubu; Wakabayashi, Kenta;...
# 2        28158154  Patent; Lianhua Science And Technology (Shangh...
# 3        38472089  Patent; HINMAN, Andrew W.; Davis, Dana; Kheife...
# 4        47897146  Article; Zheng, Shaojun; Yang, Dandan; Zhu, Ru...
# ...           ...                                                ...
# 6386     35505756  Article; Shiro, Tomoya; Kakiguchi, Keisuke; Ta...
# 6387     53330756  Article; Skotnitzki, Juri; Kremsmair, Alexande...
# 6388     53330754  Article; Skotnitzki, Juri; Kremsmair, Alexande...
# 6389     10309219  Article; Williams, David R.; Kammler, David C....
# 6390     35377477  Article; Yamada, Shigeyuki; Takahashi, Toshio;...
#
#                               Reaction: Links to Reaxys  \
# 0     https://www.reaxys.com/reaxys/secured/hopinto....
# 1     https://www.reaxys.com/reaxys/secured/hopinto....
# 2     https://www.reaxys.com/reaxys/secured/hopinto....
# 3     https://www.reaxys.com/reaxys/secured/hopinto....
# 4     https://www.reaxys.com/reaxys/secured/hopinto....
# ...                                                 ...
# 6386  https://www.reaxys.com/reaxys/secured/hopinto....
# 6387  https://www.reaxys.com/reaxys/secured/hopinto....
# 6388  https://www.reaxys.com/reaxys/secured/hopinto....
# 6389  https://www.reaxys.com/reaxys/secured/hopinto....
# 6390  https://www.reaxys.com/reaxys/secured/hopinto....
#
#                                            Reactant 1  \
# 0                                   BrC1=CC=CC(Br)=N1
# 1                      BrC1=CC=CC(=N1)C1=NC(Br)=CC=C1
# 2                                  ClC1=CC=C(C=C1)C#N
# 3                        COCOC1=CC(OCOC)=C(Br)C(C)=C1
# 4                                           Cl[Zn]C#C
# ...                                               ...
# 6386  ClC1=CC=CC=C1C1=NC2=C(N1)C1=C(NC2=O)C=C(Br)C=C1
# 6387                                     CCCCCC\C=C\I
# 6388                                     CCCCCC\C=C\I
# 6389                        CC(O)C=CCC[C@H](C)C\C=C\I
# 6390            F\C(C(=O)OCC1=CC=CC=C1)=C(/F)C(F)(F)F
#
#                                              Reactant 2  \
# 0                                     Br[Zn]C1=NC=CC=C1
# 1                                     Br[Zn]C1=NC=CC=C1
# 2                                     Cl[Zn]C1=CC=CC=C1
# 3                                        Br[Zn]C1CCCCC1
# 4                                     I\C=C\CCOC1CCCCO1
# ...                                                 ...
# 6386                                           CC[Zn]CC
# 6387     C[C@@H](C[C@@H](C)C1=CC=CC=C1)[Zn]S[Si](C)(C)C
# 6388  C[C@H](C[C@H](C)C1=CC=CC=C1)[Zn]C([Si](C)(C)C)...
# 6389                                       C\C=C\[Zn]Br
# 6390                                     CC(C)[Zn]C(C)C
#
#                                                 Product  Yield  \
# 0                            BrC1=CC=CC(=N1)C1=NC=CC=C1  0.540
# 1               BrC1=NC(=CC=C1)C1=NC(=CC=C1)C1=NC=CC=C1  0.524
# 2                           N#CC1=CC=C(C=C1)C1=CC=CC=C1  0.650
# 3                    COCOC1=CC(OCOC)=C(C2CCCCC2)C(C)=C1  0.850
# 4                                   C#C\C=C\CCOC1CCCCO1  0.910
# ...                                                 ...    ...
# 6386  CCC1=CC2=C(C=C1)C1=C(N=C(N1)C1=C(Cl)C=CC=C1)C(...  0.820
# 6387          CCCCCC\C=C\[C@@H](C)C[C@@H](C)C1=CC=CC=C1  0.100
# 6388          CCCCCC\C=C\[C@@H](C)C[C@@H](C)C1=CC=CC=C1  0.550
# 6389                     C\C=C\C=C\C[C@@H](C)CCC=CC(C)O  0.740
# 6390          CC(C)C(\C(F)(F)F)=C(\F)C(=O)OCC1=CC=CC=C1  0.910
#
#                          Reagent 1    Reagent 2 Reagent 3 Reagent 4 Solvent 1  \
# 0                               M1          NaN       NaN       NaN        S1
# 1                               M1          NaN       NaN       NaN        S1
# 2                              M22          NaN       NaN       NaN        S1
# 3                               L9           M4       NaN       NaN        S1
# 4     tetrabutyl ammonium fluoride  acetic acid       NaN       NaN        S1
# ...                            ...          ...       ...       ...       ...
# 6386                            M7          NaN       NaN       NaN        S1
# 6387                           M10          NaN       NaN       NaN        S8
# 6388                           M10          NaN       NaN       NaN        S8
# 6389                            M1          NaN       NaN       NaN        S1
# 6390             copper(l) cyanide           A1        A7       NaN        S4
#
#      Solvent 2            Solvent 3 Temp
# 0          NaN                  NaN   T2
# 1          NaN                  NaN   T2
# 2          NaN                  NaN   T1
# 3          NaN                  NaN   T2
# 4          NaN                  NaN   T2
# ...        ...                  ...  ...
# 6386        S3  Hexachlorobutadiene   T1
# 6387        S4              pentane   T1
# 6388        S4              pentane   T1
# 6389        S8              pentane   T1
# 6390        S1                   S9   T1
#
# [6391 rows x 15 columns]

# %% [markdown]
# ### Build new dataset for statistical & chemical space analysis

# %%
pdt_df = data_df[['Product', 'Yield']]

# %%
pdt_df
# Out:
#                                                 Product  Yield
# 0                            BrC1=CC=CC(=N1)C1=NC=CC=C1  0.540
# 1               BrC1=NC(=CC=C1)C1=NC(=CC=C1)C1=NC=CC=C1  0.524
# 2                           N#CC1=CC=C(C=C1)C1=CC=CC=C1  0.650
# 3                    COCOC1=CC(OCOC)=C(C2CCCCC2)C(C)=C1  0.850
# 4                                   C#C\C=C\CCOC1CCCCO1  0.910
# ...                                                 ...    ...
# 6386  CCC1=CC2=C(C=C1)C1=C(N=C(N1)C1=C(Cl)C=CC=C1)C(...  0.820
# 6387          CCCCCC\C=C\[C@@H](C)C[C@@H](C)C1=CC=CC=C1  0.100
# 6388          CCCCCC\C=C\[C@@H](C)C[C@@H](C)C1=CC=CC=C1  0.550
# 6389                     C\C=C\C=C\C[C@@H](C)CCC=CC(C)O  0.740
# 6390          CC(C)C(\C(F)(F)F)=C(\F)C(=O)OCC1=CC=CC=C1  0.910
#
# [6391 rows x 2 columns]

# %% [markdown]
# ### Calculate representative molecular descriptors in RDKit
# 16 properties are computed for each SMILES with successful RDKit mol generation.<br>
# Unsuccessful mol generation returns null property vectors.

# %%
MolWt = []
MolLogP = []
TPSA = []
HeavyAtomCount = []
NumHeteroatoms = []
NumValenceElectrons = []
NumHAcceptors = []
NumHDonors = []
NumRotatableBonds = []
RingCount = []
NumAromaticHeterocycles = []
NumAromaticCarbocycles = []
NumSaturatedHeterocycles = []
NumSaturatedCarbocycles = []
FractionCSP3 = []
QED = []

for smi in pdt_df['Product']:
    if not Chem.MolFromSmiles(smi) == None:
        mol = Chem.MolFromSmiles(smi)
        MolWt.append(Descriptors.MolWt(mol))
        MolLogP.append(Descriptors.MolLogP(mol))
        TPSA.append(Descriptors.TPSA(mol))
        HeavyAtomCount.append(Descriptors.HeavyAtomCount(mol))
        NumHeteroatoms.append(Descriptors.NumHeteroatoms(mol))
        NumValenceElectrons.append(Descriptors.NumValenceElectrons(mol))
        NumHAcceptors.append(Descriptors.NumHAcceptors(mol))
        NumHDonors.append(Descriptors.NumHDonors(mol))
        NumRotatableBonds.append(Descriptors.NumRotatableBonds(mol))
        RingCount.append(Descriptors.RingCount(mol))
        NumAromaticHeterocycles.append(Descriptors.NumAromaticHeterocycles(mol))
        NumAromaticCarbocycles.append(Descriptors.NumAromaticCarbocycles(mol))
        NumSaturatedHeterocycles.append(Descriptors.NumSaturatedHeterocycles(mol))
        NumSaturatedCarbocycles.append(Descriptors.NumSaturatedCarbocycles(mol))
        FractionCSP3.append(Descriptors.FractionCSP3(mol))
        QED.append(Chem.QED.default(mol))
    else:
        MolWt.append('')
        MolLogP.append('')
        TPSA.append('')
        HeavyAtomCount.append('')
        NumHeteroatoms.append('')
        NumValenceElectrons.append('')
        NumHAcceptors.append('')
        NumHDonors.append('')
        NumRotatableBonds.append('')
        RingCount.append('')
        NumAromaticHeterocycles.append('')
        NumAromaticCarbocycles.append('')
        NumSaturatedHeterocycles.append('')
        NumSaturatedCarbocycles.append('')
        FractionCSP3.append('')
        QED.append('')

pdt_df['MolWt'] = MolWt
pdt_df['MolLogP'] = MolLogP
pdt_df['TPSA'] = TPSA
pdt_df['HeavyAtomCount'] = HeavyAtomCount
pdt_df['NumHeteroatoms'] = NumHeteroatoms
pdt_df['NumValenceElectrons'] = NumValenceElectrons
pdt_df['NumHAcceptors'] = NumHAcceptors
pdt_df['NumHDonors'] = NumHDonors
pdt_df['NumRotatableBonds'] = NumRotatableBonds
pdt_df['RingCount'] = RingCount
pdt_df['NumAromaticHeterocycles'] = NumAromaticHeterocycles
pdt_df['NumAromaticCarbocycles'] = NumAromaticCarbocycles
pdt_df['NumSaturatedHeterocycles'] = NumSaturatedHeterocycles
pdt_df['NumSaturatedCarbocycles'] = NumSaturatedCarbocycles
pdt_df['FractionCSP3'] = FractionCSP3
pdt_df['QED'] = QED
# Out:
# RDKit ERROR: [15:30:53] Explicit valence for atom # 17 N, 4, is greater than permitted
# RDKit ERROR: [15:30:58] Explicit valence for atom # 12 N, 5, is greater than permitted
# RDKit ERROR: [15:30:59] Explicit valence for atom # 24 C, 5, is greater than permitted
# RDKit ERROR: [15:30:59] Explicit valence for atom # 12 O, 3, is greater than permitted
# RDKit ERROR: [15:31:01] Explicit valence for atom # 16 B, 4, is greater than permitted
# RDKit ERROR: [15:31:02] Explicit valence for atom # 15 B, 4, is greater than permitted
# RDKit ERROR: [15:31:02] Explicit valence for atom # 15 O, 3, is greater than permitted
# RDKit ERROR: [15:31:04] Explicit valence for atom # 16 C, 5, is greater than permitted
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
pdt_df
# Out:
#                                                 Product  Yield    MolWt  \
# 0                            BrC1=CC=CC(=N1)C1=NC=CC=C1  0.540  235.084
# 1               BrC1=NC(=CC=C1)C1=NC(=CC=C1)C1=NC=CC=C1  0.524   312.17
# 2                           N#CC1=CC=C(C=C1)C1=CC=CC=C1  0.650  179.222
# 3                    COCOC1=CC(OCOC)=C(C2CCCCC2)C(C)=C1  0.850  294.391
# 4                                   C#C\C=C\CCOC1CCCCO1  0.910  180.247
# ...                                                 ...    ...      ...
# 6386  CCC1=CC2=C(C=C1)C1=C(N=C(N1)C1=C(Cl)C=CC=C1)C(...  0.820  323.783
# 6387          CCCCCC\C=C\[C@@H](C)C[C@@H](C)C1=CC=CC=C1  0.100  258.449
# 6388          CCCCCC\C=C\[C@@H](C)C[C@@H](C)C1=CC=CC=C1  0.550  258.449
# 6389                     C\C=C\C=C\C[C@@H](C)CCC=CC(C)O  0.740  208.345
# 6390          CC(C)C(\C(F)(F)F)=C(\F)C(=O)OCC1=CC=CC=C1  0.910  290.256
#
#       MolLogP   TPSA HeavyAtomCount NumHeteroatoms NumValenceElectrons  \
# 0      2.9061  25.78             13              3                  64
# 1      3.9681  38.67             19              4                  92
# 2     3.22528  23.79             14              1                  66
# 3     4.00812  36.92             21              4                 118
# 4      2.1091  18.46             13              2                  72
# ...       ...    ...            ...            ...                 ...
# 6386   4.2872  61.54             23              5                 114
# 6387   6.3429      0             19              0                 106
# 6388   6.3429      0             19              0                 106
# 6389   3.8621  20.23             15              1                  86
# 6390   4.1717   26.3             20              6                 110
#
#      NumHAcceptors NumHDonors NumRotatableBonds RingCount  \
# 0                2          0                 1         2
# 1                3          0                 2         3
# 2                1          0                 1         2
# 3                4          0                 7         2
# 4                2          0                 4         1
# ...            ...        ...               ...       ...
# 6386             2          2                 2         4
# 6387             0          0                 9         1
# 6388             0          0                 9         1
# 6389             1          1                 7         0
# 6390             2          0                 4         1
#
#      NumAromaticHeterocycles NumAromaticCarbocycles NumSaturatedHeterocycles  \
# 0                          2                      0                        0
# 1                          3                      0                        0
# 2                          0                      2                        0
# 3                          0                      1                        0
# 4                          0                      0                        1
# ...                      ...                    ...                      ...
# 6386                       2                      2                        0
# 6387                       0                      1                        0
# 6388                       0                      1                        0
# 6389                       0                      0                        0
# 6390                       0                      1                        0
#
#      NumSaturatedCarbocycles FractionCSP3       QED
# 0                          0            0  0.709923
# 1                          0            0  0.672168
# 2                          0            0  0.658925
# 3                          1     0.647059  0.712051
# 4                          0     0.636364  0.487036
# ...                      ...          ...       ...
# 6386                       0     0.111111  0.577864
# 6387                       0     0.578947  0.357769
# 6388                       0     0.578947  0.357769
# 6389                       0     0.571429    0.4973
# 6390                       0     0.357143  0.472364
#
# [6391 rows x 18 columns]

# %% [markdown]
# ### Convert property vector dtypes to float64

# %%
pdt_df.dtypes
# Out:
# Product                      object
# Yield                       float64
# MolWt                        object
# MolLogP                      object
# TPSA                         object
# HeavyAtomCount               object
# NumHeteroatoms               object
# NumValenceElectrons          object
# NumHAcceptors                object
# NumHDonors                   object
# NumRotatableBonds            object
# RingCount                    object
# NumAromaticHeterocycles      object
# NumAromaticCarbocycles       object
# NumSaturatedHeterocycles     object
# NumSaturatedCarbocycles      object
# FractionCSP3                 object
# QED                          object
# dtype: object

# %%
cols = list(pdt_df.columns)

# %%
cols.pop(0)
# Out:
# 'Product'

# %%
pdt_df[cols] = pdt_df[cols].apply(pd.to_numeric, errors='coerce')

# %%
pdt_df.dtypes
# Out:
# Product                      object
# Yield                       float64
# MolWt                       float64
# MolLogP                     float64
# TPSA                        float64
# HeavyAtomCount              float64
# NumHeteroatoms              float64
# NumValenceElectrons         float64
# NumHAcceptors               float64
# NumHDonors                  float64
# NumRotatableBonds           float64
# RingCount                   float64
# NumAromaticHeterocycles     float64
# NumAromaticCarbocycles      float64
# NumSaturatedHeterocycles    float64
# NumSaturatedCarbocycles     float64
# FractionCSP3                float64
# QED                         float64
# dtype: object

# %%
pdt_df
# Out:
#                                                 Product  Yield    MolWt  \
# 0                            BrC1=CC=CC(=N1)C1=NC=CC=C1  0.540  235.084
# 1               BrC1=NC(=CC=C1)C1=NC(=CC=C1)C1=NC=CC=C1  0.524  312.170
# 2                           N#CC1=CC=C(C=C1)C1=CC=CC=C1  0.650  179.222
# 3                    COCOC1=CC(OCOC)=C(C2CCCCC2)C(C)=C1  0.850  294.391
# 4                                   C#C\C=C\CCOC1CCCCO1  0.910  180.247
# ...                                                 ...    ...      ...
# 6386  CCC1=CC2=C(C=C1)C1=C(N=C(N1)C1=C(Cl)C=CC=C1)C(...  0.820  323.783
# 6387          CCCCCC\C=C\[C@@H](C)C[C@@H](C)C1=CC=CC=C1  0.100  258.449
# 6388          CCCCCC\C=C\[C@@H](C)C[C@@H](C)C1=CC=CC=C1  0.550  258.449
# 6389                     C\C=C\C=C\C[C@@H](C)CCC=CC(C)O  0.740  208.345
# 6390          CC(C)C(\C(F)(F)F)=C(\F)C(=O)OCC1=CC=CC=C1  0.910  290.256
#
#       MolLogP   TPSA  HeavyAtomCount  NumHeteroatoms  NumValenceElectrons  \
# 0     2.90610  25.78            13.0             3.0                 64.0
# 1     3.96810  38.67            19.0             4.0                 92.0
# 2     3.22528  23.79            14.0             1.0                 66.0
# 3     4.00812  36.92            21.0             4.0                118.0
# 4     2.10910  18.46            13.0             2.0                 72.0
# ...       ...    ...             ...             ...                  ...
# 6386  4.28720  61.54            23.0             5.0                114.0
# 6387  6.34290   0.00            19.0             0.0                106.0
# 6388  6.34290   0.00            19.0             0.0                106.0
# 6389  3.86210  20.23            15.0             1.0                 86.0
# 6390  4.17170  26.30            20.0             6.0                110.0
#
#       NumHAcceptors  NumHDonors  NumRotatableBonds  RingCount  \
# 0               2.0         0.0                1.0        2.0
# 1               3.0         0.0                2.0        3.0
# 2               1.0         0.0                1.0        2.0
# 3               4.0         0.0                7.0        2.0
# 4               2.0         0.0                4.0        1.0
# ...             ...         ...                ...        ...
# 6386            2.0         2.0                2.0        4.0
# 6387            0.0         0.0                9.0        1.0
# 6388            0.0         0.0                9.0        1.0
# 6389            1.0         1.0                7.0        0.0
# 6390            2.0         0.0                4.0        1.0
#
#       NumAromaticHeterocycles  NumAromaticCarbocycles  \
# 0                         2.0                     0.0
# 1                         3.0                     0.0
# 2                         0.0                     2.0
# 3                         0.0                     1.0
# 4                         0.0                     0.0
# ...                       ...                     ...
# 6386                      2.0                     2.0
# 6387                      0.0                     1.0
# 6388                      0.0                     1.0
# 6389                      0.0                     0.0
# 6390                      0.0                     1.0
#
#       NumSaturatedHeterocycles  NumSaturatedCarbocycles  FractionCSP3  \
# 0                          0.0                      0.0      0.000000
# 1                          0.0                      0.0      0.000000
# 2                          0.0                      0.0      0.000000
# 3                          0.0                      1.0      0.647059
# 4                          1.0                      0.0      0.636364
# ...                        ...                      ...           ...
# 6386                       0.0                      0.0      0.111111
# 6387                       0.0                      0.0      0.578947
# 6388                       0.0                      0.0      0.578947
# 6389                       0.0                      0.0      0.571429
# 6390                       0.0                      0.0      0.357143
#
#            QED
# 0     0.709923
# 1     0.672168
# 2     0.658925
# 3     0.712051
# 4     0.487036
# ...        ...
# 6386  0.577864
# 6387  0.357769
# 6388  0.357769
# 6389  0.497300
# 6390  0.472364
#
# [6391 rows x 18 columns]

# %% [markdown]
# ## Property vector statistical analysis

# %%
stats = pdt_df.describe().round(decimals=3)
stats.to_csv('negishi_stats.csv', index=False)
stats
# Out:
#           Yield     MolWt   MolLogP      TPSA  HeavyAtomCount  NumHeteroatoms  \
# count  6391.000  6383.000  6383.000  6383.000        6383.000        6383.000
# mean      0.711   288.295     3.888    39.464          20.400           3.920
# std       0.219   111.961     1.677    28.719           7.858           2.679
# min       0.005    82.102    -1.691     0.000           6.000           0.000
# 25%       0.590   209.248     2.815    18.460          15.000           2.000
# 50%       0.760   263.243     3.639    35.530          19.000           3.000
# 75%       0.889   339.369     4.651    55.140          24.000           5.000
# max       1.000  1209.098    17.401   213.580          80.000          28.000
#
#        NumValenceElectrons  NumHAcceptors  NumHDonors  NumRotatableBonds  \
# count             6383.000       6383.000    6383.000           6383.000
# mean               106.510          2.867       0.246              3.599
# std                 42.459          1.992       0.530              2.823
# min                 32.000          0.000       0.000              0.000
# 25%                 76.000          1.000       0.000              2.000
# 50%                 98.000          3.000       0.000              3.000
# 75%                126.000          4.000       0.000              5.000
# max                456.000         17.000       6.000             31.000
#
#        RingCount  NumAromaticHeterocycles  NumAromaticCarbocycles  \
# count   6383.000                 6383.000                6383.000
# mean       2.344                    0.680                   1.224
# std        1.238                    0.824                   0.915
# min        0.000                    0.000                   0.000
# 25%        2.000                    0.000                   1.000
# 50%        2.000                    0.000                   1.000
# 75%        3.000                    1.000                   2.000
# max        9.000                    5.000                   7.000
#
#        NumSaturatedHeterocycles  NumSaturatedCarbocycles  FractionCSP3  \
# count                  6383.000                 6383.000      6383.000
# mean                      0.134                    0.149         0.297
# std                       0.392                    0.494         0.213
# min                       0.000                    0.000         0.000
# 25%                       0.000                    0.000         0.118
# 50%                       0.000                    0.000         0.273
# 75%                       0.000                    0.000         0.450
# max                       4.000                    4.000         0.943
#
#             QED
# count  6383.000
# mean      0.615
# std       0.170
# min       0.036
# 25%       0.529
# 50%       0.649
# 75%       0.741
# max       0.946

# %% [markdown]
# ## Plot yield distribution
# Note 'ax.hist' can be replaced with 'ax.kde' for kernel density estimation

# %%
yield_hist, ax = plt.subplots(figsize=(5, 5))
ax.hist(pdt_df['Yield'], bins=20, rwidth=0.9, color=plt.get_cmap('winter')(0.27))
ax.set_xlabel('yield')
ax.set_ylabel('frequency')
yield_hist.savefig('negishi_yield_hist.png', dpi=300, bbox_inches='tight')

# %%
plt.close(yield_hist)

# %% [markdown]
# ## Plot descriptor distributions
# Again, 'axis.hist' can be replaced with 'axis.kde'

# %%
props = pdt_df.drop(['Product', 'Yield'], axis=1)

# %%
prop_hists, axes = plt.subplots(4, 4, figsize=(20, 20))
cmap = plt.get_cmap('winter')
kn = np.arange(len(props.columns))
for col, axis, k in zip(props.columns, axes.flatten(), kn):
    series = props[col]
    #removing outliers to avoid sparse tail distribution
    data = series[series.between(series.quantile(.01), series.quantile(.99))]
    axis.hist(data, rwidth=0.9, color=cmap(float(k)/kn.max()))
    axis.set_xlabel(col, fontsize=12)
    if (k+1)%4 == 1%4:
        axis.set_ylabel('frequency')
prop_hists.savefig('negishi_prop_hists.png', dpi=300, bbox_inches='tight')

# %%
plt.close(prop_hists)

# %% [markdown]
# # Negishi dictionary analysis

# %%
dict_df = pd.read_csv('negishi_dict_final.csv')
dict_df.head()
# Out:
#   metal_bin                                     metal_name  metal ligand_bin  \
# 0        M1      tetrakis(triphenylphosphine) palladium(0)   1902         L1
# 1        M2      tris-(dibenzylideneacetone)dipalladium(0)    572         L2
# 2        M3  bis-triphenylphosphine-palladium(II) chloride    418         L3
# 3        M4                            palladium diacetate    370         L4
# 4        M5         bis(dibenzylideneacetone)-palladium(0)    344         L5
#
#                                          ligand_name  ligand additive_bin  \
# 0              1,1'-bis-(diphenylphosphino)ferrocene   233.0           A1
# 1  dicyclohexyl-(2',6'-dimethoxybiphenyl-2-yl)-ph...   196.0           A2
# 2                                              XPhos   187.0           A3
# 3                                 triphenylphosphine   161.0           A4
# 4                            trifuran-2-yl-phosphane   128.0           A5
#
#                  additive_name  additive solvent_bin  \
# 0             lithium chloride     243.0          S1
# 1                         zinc     207.0          S2
# 2             copper(l) iodide     154.0          S3
# 3                        water      62.0          S4
# 4  diisobutylaluminium hydride      59.0          S5
#
#                 solvent_name  solvent temperature_bin temperature_name  \
# 0            tetrahydrofuran   4525.0              T1             T<18
# 1     N,N-dimethyl-formamide   1003.0              T2          18≤T<23
# 2  1-methyl-pyrrolidin-2-one    674.0              T3          23≤T<50
# 3                    toluene    541.0              T4          50≤T<61
# 4                1,4-dioxane    335.0              T5          61≤T<80
#
#    temperature
# 0        101.0
# 1       2313.0
# 2        643.0
# 3        975.0
# 4        658.0

# %% [markdown]
# ### Plot categorical label distributions

# %%
dict_X = ['metal_bin', 'ligand_bin', 'temperature_bin', 'solvent_bin', 'additive_bin']
dict_y = ['metal', 'ligand', 'temperature', 'solvent', 'additive']
dict_bars, dict_ax = plt.subplots(len(dict_X), 1, figsize=(15, 25))
dn = np.arange(len(dict_X))
for X, y, dax, d in zip(dict_X, dict_y, dict_ax, dn):
    sub_df = dict_df[[X, y]]
    sub_df.dropna(how='all', inplace=True)
    dax.bar(sub_df[X], sub_df[y], width=0.9, color=cmap(float(d)/dn.max()))
    dax.set_xlabel(y, fontsize=16)
    dax.set_ylabel('frequency', fontsize=14)
dict_bars.savefig('negishi_dict_bars.png', dpi=300, bbox_inches='tight')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
plt.close(dict_bars)
